# %% [markdown]
# # Рынок заведений общественного питания г. Москвы.

# %% [markdown]
# Руководством было принято решение открыть новое заведение общественного питания в г.Москва.

# %% [markdown]
# Целью данного проекта является разработка рекомендации о виде заведения, количестве посадочных мест, а также районе расположения открывающегося объекта общественного питания.
#
# Поставленая задача: исследовать рынок заведений общественного питания Москвы.

# %% [markdown]
# Известны открытые данные о заведениях общественного питания в Москве.

# %% [markdown]
# # Изучение общей информации файла
#
# Загрузим полученный файл и выведем на экран несколько строк из него:

# %%
# Подключим библиотеки:
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# Сохраним уникальный путь к файлу в перееменную path:
path = '/Users/PPC/Desktop/practica/pitanie/'
# Сохраним датафрейм в переменную df:
df = pd.read_csv(path + 'rest_data.csv')
#df.head(15)
#df.tail(15)
df.sample(15)
# Out:
#            id             object_name chain object_type  \
# 4504   152216     Фудмаркет. Галичкин   нет    ресторан
# 14782  206350  ХИНКАЛЬНЫЙ ДОМ ТБИЛИСО   нет        кафе
# 4318    72293              Чайхона №1    да    ресторан
# 7493   132211                Бородачи   нет        кафе
# 2684    28800      СТОЛОВАЯ при МГППУ   нет    столовая
# 8184   140307        Кафе-бар «Бигус»   нет        кафе
# 8685   134644      Кафе «Шоколадница»    да        кафе
# 13294  200049         Кафе «Домисоль»   нет        кафе
# 4811   149537         Bizone Антикафе   нет   кафетерий
# 1262    83559             Хлеб и Вино   нет         бар
# 12896  200567             Гришаев В.В   нет    ресторан
# 10575  182893       Masons lounge bar   нет         бар
# 13374  201662                Брусника    да        кафе
# 14901  215439                  Шикари   нет    ресторан
# 12663  202130          Старый Сычуань   нет    ресторан
#
#                                                  address  number
# 4504             город Москва, улица Новый Арбат, дом 21       0
# 14782  город Москва, Новослободская улица, дом 54, ст...      60
# 4318                 город Москва, проспект Мира, дом 28      90
# 7493             город Москва, Нагатинская улица, дом 16      42
# 2684     город Москва, Открытое шоссе, дом 24, корпус 27     290
# 8184             город Москва, Русаковская улица, дом 13      80
# 8685         город Москва, проспект Вернадского, дом 86А      60
# 13294  город Москва, Павелецкая набережная, дом 8, ст...      40
# 4811   город Москва, Ленинградское шоссе, дом 8, стро...      22
# 1262               город Москва, улица Маросейка, дом 15      54
# 12896           город Москва, Профсоюзная улица, дом 61А       0
# 10575    город Москва, улица Викторенко, дом 4, корпус 1      20
# 13374  город Москва, улица Плющиха, дом 53/25, строен...      30
# 14901             город Москва, Ходынский бульвар, дом 4      64
# 12663  город Москва, Лубянский проезд, дом 25, строен...      80

# %% [markdown]
# Изучим общую информацию о полученном файле:

# %%
df.info()
# Отдельно выведем название столбцов:
df.columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15366 entries, 0 to 15365
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           15366 non-null  int64
#  1   object_name  15366 non-null  object
#  2   chain        15366 non-null  object
#  3   object_type  15366 non-null  object
#  4   address      15366 non-null  object
#  5   number       15366 non-null  int64
# dtypes: int64(2), object(4)
# memory usage: 720.4+ KB
# Index(['id', 'object_name', 'chain', 'object_type', 'address', 'number'], dtype='object')

# %% [markdown]
# Описание данных:
#
# • object_name — название объекта общественного питания;
#
# • chain — сетевой ресторан;
#
# • object_type — тип объекта общественного питания;
#
# • address — адрес;
#
# • number — количество посадочных мест.
#
# Полученный файл состоит из 15366 строк и 6 столбцов. Два столбца: id, number содержат количественную переменную, остальные 4 - категориальную. В столбцах пропусков нет. Совершать замену типа данных в столбцах - не нужно. Возможно есть дубликаты.
#
# # Вывод:
# Каждая строка датафрейма df содержит информацию об конкретном объекте общественного питания в г.Москва: название заведения, тип объекта: кафе, ресторан и др., адрес расположения; а также - количество посадочных мест; является заведение сетевым: да/нет.
#
# Переходим к предобработке данных.

# %% [markdown]
# # Предобработка данных.
#
# Выведем первые пять строк датафрейма:

# %%
df.head(5)
# Out:
#        id             object_name chain object_type  \
# 0  151635                 СМЕТАНА   нет        кафе
# 1   77874                  Родник   нет        кафе
# 2   24309         Кафе «Академия»   нет        кафе
# 3   21894              ПИЦЦЕТОРИЯ    да        кафе
# 4  119365  Кафе «Вишневая метель»   нет        кафе
#
#                                              address  number
# 0         город Москва, улица Егора Абакумова, дом 9      48
# 1  город Москва, улица Талалихина, дом 2/1, корпус 1      35
# 2          город Москва, Абельмановская улица, дом 6      95
# 3            город Москва, Абрамцевская улица, дом 1      40
# 4  город Москва, Абрамцевская улица, дом 9, корпус 1      50

# %% [markdown]
# Выведем уникальные типы объекта общественного питания:

# %%
df['object_type'].unique()
# Out:
# array(['кафе', 'столовая', 'закусочная',
#        'предприятие быстрого обслуживания', 'ресторан', 'кафетерий',
#        'буфет', 'бар', 'магазин (отдел кулинарии)'], dtype=object)

# %% [markdown]
# Дубликатов нет.

# %% [markdown]
# Сейчас проверим названия общественных заведений(столбец object_name). Взглянув на данные указанного столбца, сразу видим, что названия написаны в разном регистре - это нужно исправить, чтобы исключить "неявные дубликаты". Но там могут быть и другие "ошибки". Постараемся привести все названия к одному виду. Выведем на экран данные содержащие только сетевые заведения (думаю что "ошибок" больше в этих данных, т.к. они повторяются):

# %%
# Переведем все названия в нижний регистр:
df['object_name'] = df['object_name'].str.lower()
# Создадим отдельный датафрейм с сетевыми заведениями:
chain_yes = df[df['chain'] == "да"].copy()
# Выведем уникальные названия заведений:
chain_yes['object_name'].unique()
# Out:
# array(['пиццетория', 'брусника', 'алло пицца', 'суши wok', 'тануки',
#        "домино'с пицца", 'готика', 'му-му', 'хлеб насущный', 'tajj mahal',
#        'данкин донатс', 'вареничная №1', 'шоколадница', 'теремок',
#        'хинкальная', 'шантимель', 'хинкальная city', 'кружка', 'суши вок',
#        'примавера', 'виктория', 'пиццерия «академия»', 'чебуречная ссср',
#        'макдоналдс', 'grand cru', 'чайхона №1', 'панчо пицца', 'kfc',
#        'сабвей', 'ресторан «якитория»', 'советские времена',
#        'кафе «андерсон»', 'кафе «subway»', 'ресторан «макдоналдс»',
#        'суши сет', 'шоколад', 'тирольские пироги', 'гамбринус',
#        'пицца фабрика', 'subway', 'кафе «якитория»', 'кафе «тануки»',
#        'сити пицца', 'кофе хаус',
#        'кулинарная лавка братьев караваевых братья караваевы', 'прайм',
#        'пицца экспресс', 'шоколадница кофе хаус', 'николай', 'якитория',
#        'магнолия', 'кофе с собой', 'джаганнат', 'волконский', 'moskalyan',
#        'гино-но-таки', 'тратория semplice', 'ньокки', 'хижина',
#        'додо пицца', 'крошка картошка', 'бургер кинг', 'папа джонс',
#        'кондитерская волконский', 'бар- буфет «николай»',
#        'ресторан «тануки»', 'две палочки', 'джон джоли', 'ваби-саби',
#        'кофемания', 'простые вещи', 'павлин-мавлин',
#        'кафе «чайхана тапчан»', 'штолле', 'бабай клаб', 'андерсон',
#        'кофе хаус. экспрессо и капучино бар', 'кактус', 'темпл бар',
#        'хлеб&co', 'кофе-бин', 'французская выпечка',
#        'кофейня «кофе хаус»', 'планета суши', 'де марко',
#        'ресторан «илья муромец»', 'ресторан «корчма тарас бульба»',
#        'кофейня «шоколадница»', 'стейк хаус гудман', 'иль патио',
#        'иль-патио', 'мюнгер', 'ботик петра', 'кафе «папа джонс»',
#        'кафе «штолле»', 'чин чин', 'правdа кофе', 'сити', 'krispy creme',
#        'prime прайм стар', 'азбука вкуса', 'ресторан «джон джоли»',
#        'пивко', 'пиццерия «папа джонс»', 'ресторан «брудер»', 'мимино',
#        'кофепорт', 'кафе «пицца фабрика»', 'прайм стар',
#        'цинандали хинкальная', 'иль форно', 'travelers coffee',
#        'рецептор', 'сушишоп', 'кофе-хаус', 'баскин роббинс', 'барашка',
#        'корчма «тарас бульба»', 'кафе «шоколадница»', 'пицца хат',
#        'мята lounge', 'costa coffee', 'илья муромец', 'ёрш', 'стардогs',
#        'корчма тарас бульба', 'upside down cake', 'кафе пекарня хачапури',
#        'домашнее кафе сеть городских кафе', 'ресторан тануки',
#        'бар-буфет николай', 'добрынинский и партнёры',
#        'кофейня «де марко»', 'менза', 'тапчан', 'колбасофф',
#        'крепери де пари', 'брава коста кофе', 'старбакс starbucks',
#        'венеция', 'жан жак', 'гурмания',
#        'кулинарная лавка братьев караваевых', 'кафе «тапчан»',
#        'ресторан «ньокки»', 'bierloga', 'штирбирлиц', 'маки-маки',
#        'хачапури', 'в&в бургер', 'jeffreys coffee', 'travelers coffe',
#        'академия', 'дабл би', 'золотая вобла', 'пилзнер',
#        'траттория примавера', 'праймкафе прайм стар',
#        "пиццерия «домино'с пицца»", 'кафе «суши сет»', 'коста кофе',
#        'перекресток', 'starbucks', 'руккола', 'иль патио планета суши',
#        'кафе «starbucks»', 'шантимель (кондитерские)', 'милано пицца',
#        'зодиак', 'ресторан «ёрш»', 'торро гриль',
#        'фитнес-бар «world class»', 'роллофф', 'кафе «кулинарное бюро»',
#        'билла', 'урюк', 'кофейня «старбакс»', 'кафе «кружка»',
#        'tokyo bay', 'кулинарное бюро', 'пиппони', 'пицца пипони',
#        'детское кафе «андерсон»', 'кафе «хлеб насущный»',
#        'кулинарное бюро китчен', 'сытая утка', 'икура паб', 'сварня',
#        'детский клуб «андерсон»', 'пиццерия пиу дель чибо',
#        'предприятие быстрого обслуживания «бургер кинг»',
#        'предприятие быстрого обслуживания «крошка картошка»',
#        'предприятие быстрого обслуживания «макдоналдс»',
#        'предприятие быстрого обслуживания «теремок»', 'ичибан боши',
#        'макс бреннер', 'бутчер бизон', 'магбургер азс №16',
#        'магазин-кулинария «суши сет»', 'магбургер азс №17',
#        'кондитерская-пекарня волконский', 'il forno иль форно',
#        'кафе «prime» прайм стар', 'то да сё', 'пицца pomodoro',
#        'бургер кинг burger king', 'чешская пивная «козловица»',
#        'ресторан джон джоли', 'грабли', 'vietcafe вьеткафе', 'оникс',
#        'пицца pomodoro и суши дзен', 'вьеткафе', 'да пино',
#        'старина миллер', 'кафе рецептор', 'якитория и ян примус',
#        'старина мюллер старина миллер', 'кафе кофемания', 'хинкальная №1',
#        'пронто', 'пицца «паоло»', 'лепешка', 'чешская пивная «пилзнер»',
#        'пироги штолле', 'гурман', 'территория ясенево', 'сабвей сушивок',
#        'городские автокофейни', 'вгости. урюк', 'порто мальтезе',
#        'мимино хинкальная', 'квартира 44', 'хинкальная кинто',
#        'американ сити пицца цех по изготовлению пиццы',
#        'ресторан «чайхона №1»', 'бар азбука вкуса', 'суп кафе',
#        'ресторан «florentini»', 'поль бейкери', 'кафе «му-му»',
#        'glowsubs sandwiches', 'ми пьяче', 'кафе «хинкальная»',
#        'закусочная «сушишоп»', 'ресторан «территория»', 'кафе «kfc»',
#        'кафе «пицца хат»', 'пиццерия донателло',
#        'закусочная «американ сити пицца»',
#        'предприятие быстрого обслуживания «сушишоп»', 'нияма пицца пи',
#        'кафе «ваби-саби»', 'кафе «марукамэ»', 'кафе чайхона №1',
#        'бир хаус', 'спб', 'кебаб хаус', 'прайм-кафе', 'paul поль',
#        'шашлык-машлык', 'генацвали', 'территория timbigfamily',
#        'территория', 'да пино (da pino)', 'ресторан «золотая вобла»',
#        'кафе prime прайм стар', 'граци рагацци зю кафе', 'виват-пицца',
#        'ресторан «вьеткафе»', 'пироговая штолле', 'сабвей subway',
#        'starlite diner', 'прайм-кафе прайм стар', 'старбакс',
#        'ресторан «урюк»', 'krispy krem', 'кофе хаус,экспресс',
#        'ростикс kfc', 'ресторан «иль патио»', 'ресторан маки-маки',
#        'кофейня шоколадница', 'кафе пронто', 'кафе якитория', 'кофетун',
#        'ташир пицца', 'ресторан хинкальная', 'закусочная kfc',
#        'елки-палки', 'кафе кофе тун', 'метро к&к', 'тамаси суши',
#        'burger club', 'фантоцци рус', 'кафе «урюк» хивинская чайхона',
#        'ресторан «пронто»', 'изба', 'воккер', 'нияма', 'ганс и марта',
#        'кафе «поль бейкери»', 'кафе «сабвей» старбакс',
#        'kfc волгоградский', 'кофе', 'кафе «теремок»', 'ливан-хаус',
#        'лето', 'суши бар «маки-маки»', 'ямми микс', 'брудер', 'баракат',
#        'кафе при азс', 'урюк вавилова', 'кафе теремок',
#        'кулинарное бюро kitchen', 'москва - макдоналдс', 'теремок инвест',
#        'ресторан«вьеткафе»', 'кафе космик', 'сушиман', 'кафе шоколад',
#        'япоша', 'кофе тун', 'барбарис', 'yogurt frenzy', 'bocconcino',
#        'помидор', 'дюшес', 'чайхона №1 бутово', 'кафе «то да сё»',
#        'кафе «старбакс»', 'урожай', 'ресторан «ян примус»', 'шварцвальд',
#        'tutti frutti frozen yogurt', 'кафе «нияма»', 'кафе «менза»',
#        'ресторан «джардино да пино»', 'кафе «меленка»',
#        'кафе «кофейня старбакс»', 'ресторан «колбасофф»',
#        'кафе макдоналдс', 'кафе kfc', 'сбарро', 'кафе «макдоналдс»',
#        'кафе «восточный базар»', 'кафе кофе-хаус', 'кафе starbucks',
#        'ресторан «космик»', 'каро', 'пбо «kfc покрышкина»',
#        'кофейня «старбакс кофе»', 'ресторан «планета суши»',
#        'white rabbite (белый кролик)', 'бакинский бульвар', 'ян примус',
#        'кафе му-му', 'кафе «prime» (прайм стар)', 'healthy food',
#        'sushilka', 'coffeeshop company', 'теремок-инвест', 'maki maki',
#        'ресторан«макдоналдс»', 'стейк-хаус гудман', 'барбекю',
#        'обжорный ряд', 'космик', 'тайм авеню', 'братья караваевы',
#        'стардогs и шаурма', 'wok & box', 'кафе при азс газпромнефть',
#        'старбакс кофе', 'бар боулинг-космик', 'ресторан «темпл бар»',
#        'закусочная «бургер кинг»', 'ресторан «чайхана урюк»',
#        'прайм стар кафе', 'кофе с собой gate 42',
#        'кафе-закусочная «бургер кинг»', 'кафе «торнадо»', 'магбургер',
#        'ресторан «теремок»', 'ресторан «бакинский бульвар»',
#        "предприятие быстрого обслуживания «домино'с пицца»",
#        'кафе «прайм стар»',
#        'предприятие быстрого обслуживания «бенто wok»',
#        'предприятие быстрого обслуживания «kfc»', 'бургер клаб',
#        'кафе «кофе хаус»', 'кафе при азс «bp»', 'wokker', 'ариана',
#        'кафе «суши вок»', 'кафе «бургер кинг»', 'папа джонс пицца',
#        'закусочная «теремок»', 'закусочная «крошка картошка»',
#        'спорт-бар «космик»', 'ресторан японской кухни «маки-маки»',
#        'детское кафе «космик»', 'ванвок', 'шикари иль патио',
#        'кафе «данкин донатс»', 'ресторан «бургер кинг»',
#        'кафе «крошка картошка»', 'закусочная «kfc»',
#        'закусочная «пицца хат»', 'кафе «costa coffee»', 'каффе «wokker»',
#        'семейный ресторан «космик»', 'кафе иль патио «il patio»',
#        'кофейня «дабл би»', 'ресторан kfc',
#        'ресторан быстрого питания «крошка картошка»', 'starbucks кофе',
#        'пражечка', 'павлин мавлин чайхона №1', 'блинная', 'correas',
#        'мистер картошка', 'кафе «сим-сим»', 'pizengof99 спб', 'меленка',
#        'югос', 'марчеллис', 'кафе песто и митлес',
#        'ресторан «вареничная №1»', 'молли гвинз', 'шоколадница кофемания',
#        'дорогая я перезвоню', 'm cafe хинкальная', 'marrakesh хинкальная',
#        'кофейня кофемания, пиццерия бармалини',
#        'кофешоп coffeeshop company', 'гудман гудвин', 'гудман',
#        'torro grill торро гриль', 'ресторан торро гриль', 'the terrace',
#        'бир хаус паб', 'вlack burger чайхона №1',
#        'пончиковое кафе икеа ikea', 'ресторан икеа ikea', 'black & white',
#        'пиццерия «додо пицца»', 'роснефть', 'upside down', 'пбо «kfc»',
#        'пбо «теремок»', 'starbucks, старбакс кофе',
#        'кофейня «costa coffee»', 'cookhouse', 'dunkin donuts',
#        'мск московская сеть кальянных', 'братья караваевых',
#        'кафе бургер кинг',
#        'предприятие быстрого обслуживания «магбургер»',
#        'кафе «баскин роббинс»', 'пицца паоло', 'cofix', 'пикколо',
#        'милти', 'сеть магазинов «суши wok»', 'васаби',
#        'грузинская кухня эzо хинкальная', 'кафе быстрого питания му-му',
#        'кафе суши wok', 'хачапури, одесса -мама', 'tgi fridays',
#        'deli by prime прайм-кафе', 'пицерия «папа джонс»', 'дабл би блэк',
#        'точка продажи готовой еды милти',
#        'предприятие быстрого обслуживания «додо пицца»',
#        'суши «маки-маки»', 'семейное кафе и кондитерская «андерсон»',
#        'пиццерия папа джонс', 'grand урюк', 'кафе волконский пекарня',
#        'panda express', 'ав-дейли азбука вкуса', 'ирландский паб',
#        'ресторан «kfc»', 'кафе мороженного «tutti frutti»',
#        'кафе «суши wok»', 'бар «суши wok»', "ресторан «домино'с пицца»",
#        'tutti frutti', 'кафе prime прайм стар прайм-кафе',
#        'prime прайм стар прайм-кафе', "кафе «домино'с пицца»",
#        'кафе-пекарея «волконский»', 'нияма. пицца пи', 'алло пицца 2',
#        'бистро пронто', 'зю кафе', 'восточный базар', 'сказка',
#        'ресторан «хинкальная»', 'ресторан «пицца хат»', 'вкусняшка',
#        'грузинские каникулы барбарис', 'стардогс стардогs',
#        'суши тун, хруст pizza, кофе тун', 'кофе с собой «кофейня»',
#        'пиццерия «пицца паоло»', 'кафе при азс лукойл',
#        'лукойл-центрнефтьпродукт', 'fridays', 'мираторг',
#        'закусочная «баскин роббинс & стардогс»', 'бенто wok',
#        'кафе «иль патио»', 'bubbleology', 'starbucks старбакс',
#        'бодрый день кофе с собой', 'boobo', 'кальянная мята lounge',
#        'кальян-бар «мята lounge»', 'кальян- бар «мята lounge»',
#        'паб кружка', 'luciano', 'пиццерия «пицца хат»', 'лукойл',
#        'мята lounge шаболовка', 'кальянная f-lounge',
#        'мск московская сеть кальянных на шаболовке',
#        'семейное кафе андерсон',
#        '«кафе «кулинарная лавка братьев караваевых»»',
#        'кафе «кулинарная лавка братьев караваевых»',
#        '«кафе «кулинарная лавка братьев караваевых»',
#        "домино'с пицца domino,s pizza", 'чешская пивная пилзнер',
#        'beverly hills diner', 'кафе штолле',
#        'предприятие быстрого питания «крошка картошка»', 'florentini',
#        'кондитерия тирольские пироги', 'lavkalavka', 'хлебница пекарня',
#        'кальян-бар moskalyan', 'анти-кафе кальянная «moskalyan»',
#        'советские времена чебуречная ссср', 'мята lounge автозаводская',
#        'osteria mario', 'мясоroob', 'газпромнефтьцентр',
#        'якитория и спорт бар', 'японский ресторан «ваби-саби»',
#        'goodman гудман', 'prime star прайм стар', 'праймстар',
#        'coffeeshop', 'my box', 'vanwok ванвок', 'van wok ванвок',
#        'бб энд бургерс в&в бургер', 'закусочная «стардогs»', 'сувлаки',
#        'суши тун', 'пицца паоло и бенто wok', 'starbucks coffee',
#        'кофемания starbucks', 'movenpick', 'fridays kfc',
#        'ресторан быстрого питания kfc', 'marmalato',
#        'предприятие быстрого обслуживания «милти»',
#        'магазин готовой еды «милти»', 'готовые блюда милти',
#        'лаундж-бар «мята lounge»', 'бар мята lounge',
#        'мята lounge октябрьская', 'кальянная «мята lounge»', 'мята'],
#       dtype=object)

# %% [markdown]
# Количество уникальных названий заведений общественного питания:

# %%
chain_yes['object_name'].nunique()
# Out:
# 577

# %% [markdown]
# Просмотрев названия общественных заведений, выполним следующие преобразования для всех ячеек столбца 'object_name', чтобы привести данные к одному виду:
#
# 1. Оставим названия только из кавычек;
#
# 2. Удалим типы объектов общественного питания из названий: кафе, столовая и т.д., а также слова: москва, при, семейное и др.;
#
# 3. Удалим образовавшиеся пробелы, "-" и др. в начале и в конце строки;
#
# 4. Сделаем замены: ВОК на WOK, САБВЕЙ на SABWAY, ИЛЬ-ПАТИО(ИЛЬ ПАТИО, IL PATIO) на ILPATIO, ВЬЕТ на VIETCAFE;
#
# Приступим:
#
# Чтобы оставить названия только из кавычек: воспользуемся методом findall() библиотеки re, в качестве аргумента передадим регулярное выражение: '«(.*)»'. Данные будут сохранены в новый столбец. Затем в новом столбце данные переведем в строку с помощью join() и пропуски заменим на названия из object_name с помощью метода .loc:

# %%
import re # Подключаем библиотеку re (для работы с регулярными выражениями)
# Создаем новый столбец object_name_new с помощью apply(), в качестве аргумента которой передаем функцию, 
#которая оставляет только данные из кавычек с помощью метода findall
df['object_name_new'] = df['object_name'].apply(lambda x: re.findall('«(.*)»', x))
df.head(5)
# Out:
#        id             object_name chain object_type  \
# 0  151635                 сметана   нет        кафе
# 1   77874                  родник   нет        кафе
# 2   24309         кафе «академия»   нет        кафе
# 3   21894              пиццетория    да        кафе
# 4  119365  кафе «вишневая метель»   нет        кафе
#
#                                              address  number  \
# 0         город Москва, улица Егора Абакумова, дом 9      48
# 1  город Москва, улица Талалихина, дом 2/1, корпус 1      35
# 2          город Москва, Абельмановская улица, дом 6      95
# 3            город Москва, Абрамцевская улица, дом 1      40
# 4  город Москва, Абрамцевская улица, дом 9, корпус 1      50
#
#      object_name_new
# 0                 []
# 1                 []
# 2         [академия]
# 3                 []
# 4  [вишневая метель]

# %%
# Данные переводим в строку:
df['object_name_new'] = [''.join(x) for x in df['object_name_new']]
df.head(5)
# Out:
#        id             object_name chain object_type  \
# 0  151635                 сметана   нет        кафе
# 1   77874                  родник   нет        кафе
# 2   24309         кафе «академия»   нет        кафе
# 3   21894              пиццетория    да        кафе
# 4  119365  кафе «вишневая метель»   нет        кафе
#
#                                              address  number  object_name_new
# 0         город Москва, улица Егора Абакумова, дом 9      48
# 1  город Москва, улица Талалихина, дом 2/1, корпус 1      35
# 2          город Москва, Абельмановская улица, дом 6      95         академия
# 3            город Москва, Абрамцевская улица, дом 1      40
# 4  город Москва, Абрамцевская улица, дом 9, корпус 1      50  вишневая метель

# %%
# Переносим остальные названия из столбца object_name в пустые ячейки object_name_new:
df.loc[df['object_name_new'] == '', 'object_name_new'] = df['object_name']
df.head(5)
# Out:
#        id             object_name chain object_type  \
# 0  151635                 сметана   нет        кафе
# 1   77874                  родник   нет        кафе
# 2   24309         кафе «академия»   нет        кафе
# 3   21894              пиццетория    да        кафе
# 4  119365  кафе «вишневая метель»   нет        кафе
#
#                                              address  number  object_name_new
# 0         город Москва, улица Егора Абакумова, дом 9      48          сметана
# 1  город Москва, улица Талалихина, дом 2/1, корпус 1      35           родник
# 2          город Москва, Абельмановская улица, дом 6      95         академия
# 3            город Москва, Абрамцевская улица, дом 1      40       пиццетория
# 4  город Москва, Абрамцевская улица, дом 9, корпус 1      50  вишневая метель

# %% [markdown]
# Чтобы удалить типы объектов общественного питания из названий: кафе, столовая и т.д., а также слова: москва, при, кофейня, семейное, пиццерия и др.: к данным столбца object_name_new применим строковый метод replace, где в качестве первого аргумента будем передавать регулярные выражения, а в качестве второго аргумента укажем пусто: '':

# %%
df['object_name_new'] = df['object_name_new']\
       .str.replace('(моск[\w]+)|(ресторан)|(быстр[\w]+)|(питан[\w]+)|(кафе)|(бар)|(обсл[\w]+)|(закусочная)|\
        (при)?|(сем[\w]+)|(пир[\w]+)|(буфет)|(стол[\w]+)?|(пиццер[\w]+)|(ооо)|(кальян[\w]+)|\
        (точка)|(готов[\w]+)|(ед.)|(блюд[\w]+)|(сеть)|(город[\w]+)|(прод[\w]+)|(пончик[\w]+)|(кулинар[\w]+)|\
        (burger king)|(лавка)|(покрышкина)|(кофейня)', '')
df.head(10)
# Out:
#        id               object_name chain object_type  \
# 0  151635                   сметана   нет        кафе
# 1   77874                    родник   нет        кафе
# 2   24309           кафе «академия»   нет        кафе
# 3   21894                пиццетория    да        кафе
# 4  119365    кафе «вишневая метель»   нет        кафе
# 5   27429  стол. при гоу сош № 1051   нет    столовая
# 6  148815                  брусника    да        кафе
# 7   20957               буфет мтуси   нет    столовая
# 8   20958               кпф семья-1   нет    столовая
# 9   28858            столовая мтуси   нет    столовая
#
#                                              address  number  \
# 0         город Москва, улица Егора Абакумова, дом 9      48
# 1  город Москва, улица Талалихина, дом 2/1, корпус 1      35
# 2          город Москва, Абельмановская улица, дом 6      95
# 3            город Москва, Абрамцевская улица, дом 1      40
# 4  город Москва, Абрамцевская улица, дом 9, корпус 1      50
# 5  город Москва, Абрамцевская улица, дом 15, корп...     240
# 6      город Москва, переулок Сивцев Вражек, дом 6/2      10
# 7  город Москва, Авиамоторная улица, дом 8, строе...      90
# 8  город Москва, Авиамоторная улица, дом 8, строе...     150
# 9  город Москва, Авиамоторная улица, дом 8, строе...     120
#
#             object_name_new
# 0                   сметана
# 1                    родник
# 2                  академия
# 3                пиццетория
# 4           вишневая метель
# 5  стол. при гоу сош № 1051
# 6                  брусника
# 7                     мтуси
# 8                    кпф -1
# 9                     мтуси

# %% [markdown]
# Чтобы удалить образовавшиеся пробелы, точку и другие спец.символы в начале и в конце строки применим строковый метод strip к данным столбца object_name_new:

# %%
df['object_name_new'] = df['object_name_new'].str.strip('(«)|(»)|( )|(.)|(-)')

# %% [markdown]
# Сделаем замены: ВОК на WOK, САБВЕЙ на SABWAY, ИЛЬ-ПАТИО(ИЛЬ ПАТИО, IL PATIO) на ILPATIO, ВЬЕТ на VIETCAFE. Применим метод replace к данным столбца object_name_total

# %%
df['object_name_new'] = df['object_name_new'].str.replace('вок', 'wok')
df['object_name_new'] = df['object_name_new'].str.replace('сабвей', 'subway')
df['object_name_new'] = df['object_name_new'].str.replace('иль[А-я-]*', 'ilpatio')
df['object_name_new'] = df['object_name_new'].str.replace('il patio', 'ilpatio')
df['object_name_new'] = df['object_name_new'].str.replace('вьет', 'vietcafe')

# %% [markdown]
# Проверим есть ли пропуски:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15366 entries, 0 to 15365
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               15366 non-null  int64
#  1   object_name      15366 non-null  object
#  2   chain            15366 non-null  object
#  3   object_type      15366 non-null  object
#  4   address          15366 non-null  object
#  5   number           15366 non-null  int64
#  6   object_name_new  15366 non-null  object
# dtypes: int64(2), object(5)
# memory usage: 840.5+ KB

# %% [markdown]
# Остались в столбце object_name_new пропуски (это потому что в названии был прописан только тип): заполним их данными из столбца object_type:

# %%
df.loc[df['object_name_new'] == '', 'object_name_new'] = df['object_type']

# %% [markdown]
# Посмотрим сколько осталось уникальных значений в столбце 'object_name_new' таблицы, содержащей информацию о сетевых заведений общественного питания:

# %%
df[df['chain'] == 'да']['object_name_new'].nunique()
# Out:
# 392

# %%
df[df['chain'] == 'да']['object_name_new'].unique()
# Out:
# array(['пиццетория', 'брусника', 'алло пицца', 'суши wok', 'тануки',
#        "домино'с пицца", 'готика', 'му-му', 'хлеб насущный', 'tajj mahal',
#        'данкин донатс', 'вареничная №1', 'шоколадница', 'теремок',
#        'хинкальная', 'шантимель', 'хинкальная city', 'кружка',
#        'примавера', 'виктория', 'академия', 'чебуречная ссср',
#        'макдоналдс', 'grand cru', 'чайхона №1', 'панчо пицца', 'kfc',
#        'subway', 'якитория', 'советские времена', 'андерсон', 'суши сет',
#        'шоколад', 'тирольские', 'гамбринус', 'пицца фабрика',
#        'сити пицца', 'кофе хаус', 'братьев караваевых братья караваевы',
#        'прайм', 'пицца экспресс', 'шоколадница кофе хаус', 'николай',
#        'магнолия', 'кофе с собой', 'джаганнат', 'волконский', 'moskalyan',
#        'гино-но-таки', 'тратория semplice', 'ньокки', 'хижина',
#        'додо пицца', 'крошка картошка', 'бургер кинг', 'папа джонс',
#        'кондитерская волконский', 'две палочки', 'джон джоли',
#        'ваби-саби', 'кофемания', 'простые вещи', 'павлин-мавлин',
#        'чайхана тапчан', 'штолле', 'бабай клаб',
#        'кофе хаус. экспрессо и капучино', 'кактус', 'темпл', 'хлеб&co',
#        'кофе-бин', 'французская выпечка', 'планета суши', 'де марко',
#        'ilpatio муромец', 'корчма тарас бульба', 'стейк хаус гудман',
#        'ilpatio патио', 'ilpatio', 'мюнгер', 'ботик петра', 'чин чин',
#        'правdа кофе', 'сити', 'krispy creme', 'prime прайм стар',
#        'азбука вкуса', 'пивко', 'брудер', 'мимино', 'кофепорт',
#        'прайм стар', 'цинандали хинкальная', 'ilpatio форно',
#        'travelers coffee', 'рецептор', 'сушишоп', 'кофе-хаус',
#        'баскин роббинс', 'ашка', 'тарас бульба', 'пицца хат',
#        'мята lounge', 'costa coffee', 'ёрш', 'стардогs',
#        'upside down cake', 'пекарня хачапури', 'домашнее',
#        'добрынинский и партнёры', 'менза', 'тапчан', 'колбасофф',
#        'крепери де пари', 'брава коста кофе', 'старбакс starbucks',
#        'венеция', 'жан жак', 'гурмания', 'братьев караваевых', 'bierloga',
#        'штирбирлиц', 'маки-маки', 'хачапури', 'в&в бургер',
#        'jeffreys coffee', 'travelers coffe', 'дабл би', 'золотая вобла',
#        'пилзнер', 'траттория примавера', 'прайм прайм стар', 'коста кофе',
#        'перекресток', 'starbucks', 'руккола',
#        'ilpatio патио планета суши', 'шантимель (кондитерские',
#        'милано пицца', 'зодиак', 'торро грilpatio', 'world class',
#        'роллофф', 'бюро', 'билла', 'урюк', 'старбакс', 'tokyo bay',
#        'пиппони', 'пицца пипони', 'бюро китчен', 'сытая утка',
#        'икура паб', 'сварня', 'пиу дель чибо', 'ичибан боши',
#        'макс бреннер', 'бутчер бизон', 'магбургер азс №16',
#        'магбургер азс №17', 'кондитерская-пекарня волконский',
#        'il forno ilpatio форно', 'prime', 'то да сё', 'пицца pomodoro',
#        'бургер кинг burger king', 'козловица', 'грабли',
#        'vietcafe vietcafe', 'оникс', 'пицца pomodoro и суши дзен',
#        'vietcafe', 'да пино', 'старина миллер', 'якитория и ян примус',
#        'старина мюллер старина миллер', 'хинкальная №1', 'пронто',
#        'паоло', 'лепешка', 'гурман', 'территория ясенево',
#        'subway сушиwok', 'автокофейни', 'вгости. урюк', 'порто мальтезе',
#        'мимино хинкальная', 'квартира 44', 'хинкальная кинто',
#        'американ сити пицца цех по из пиццы', 'суп', 'florentini',
#        'поль бейкери', 'glowsubs sandwiches', 'ми пьяче', 'территория',
#        'донателло', 'американ сити пицца', 'нияма пицца пи', 'марукамэ',
#        'бир хаус', 'спб', 'кебаб хаус', 'paul поль', 'шашлык-машлык',
#        'генацвали', 'территория timbigfamily', 'да пино (da pino',
#        'граци рагацци зю', 'виват-пицца', 'subway subway',
#        'starlite diner', 'прайм- прайм стар', 'krispy krem',
#        'кофе хаус,экспресс', 'ростикс kfc', 'кофетун', 'ташир пицца',
#        'елки-палки', 'кофе тун', 'метро к&к', 'тамаси суши',
#        'burger club', 'фантоцци рус', 'изба', 'wokкер', 'нияма',
#        'ганс и марта', 'kfc волгоградский', 'кофе', 'ливан-хаус', 'лето',
#        'ямми микс', 'акат', 'при азс', 'урюк вавилова', 'бюро kitchen',
#        'теремок инвест', 'космик', 'сушиман', 'япоша', 'ис',
#        'yogurt frenzy', 'bocconcino', 'помидор', 'дюшес',
#        'чайхона №1 бутово', 'урожай', 'ян примус', 'шварцвальд',
#        'tutti frutti frozen yogurt', 'джардино да пино', 'меленка', 'сро',
#        'восточный базар', 'каро', 'старбакс кофе',
#        'white rabbite (белый кролик', 'бакинский бульвар', 'healthy food',
#        'sushilka', 'coffeeshop company', 'теремок-инвест', 'maki maki',
#        'стейк-хаус гудман', 'бекю', 'обжорный ряд', 'тайм авеню',
#        'братья караваевы', 'стардогs и шаурма', 'wok & box',
#        'при азс газпромнефть', 'боулинг-космик', 'чайхана урюк',
#        'кофе с собой gate 42', 'торнадо', 'магбургер', 'бенто wok',
#        'бургер клаб', 'bp', 'wokker', 'ариана', 'папа джонс пицца',
#        'ванwok', 'шикари ilpatio патио', 'starbucks кофе', 'пражечка',
#        'павлин мавлин чайхона №1', 'блинная', 'correas',
#        'мистер картошка', 'сим-сим', 'pizengof99 спб', 'югос',
#        'марчеллис', 'песто и митлес', 'молли гвинз',
#        'шоколадница кофемания', 'дорогая я перезвоню',
#        'm cafe хинкальная', 'marrakesh хинкальная', 'кофемания,  малини',
#        'кофешоп coffeeshop company', 'гудман гудвин', 'гудман',
#        'torro grill торро грilpatio', 'the terrace', 'бир хаус паб',
#        'вlack burger чайхона №1', 'икеа ikea', 'black & white',
#        'роснефть', 'upside down', 'starbucks, старбакс кофе', 'cookhouse',
#        'dunkin donuts', 'мск', 'братья караваевых', 'пицца паоло',
#        'cofix', 'пикколо', 'милти', 'васаби',
#        'грузинская кухня эzо хинкальная', 'хачапури, одесса -мама',
#        'tgi fridays', 'deli by prime прайм', 'дабл би блэк',
#        'точка    милти', 'grand урюк', 'волконский пекарня',
#        'panda express', 'ав-дейли азбука вкуса', 'ирландский паб',
#        'tutti frutti', 'prime прайм стар прайм', 'нияма. пицца пи',
#        'алло пицца 2', 'бистро пронто', 'зю', 'сказка', 'вкусняшка',
#        'грузинские каникулы ис', 'стардогс стардогs',
#        'суши тун, хруст pizza, кофе тун',
#        'предприятие быстрого обслуживания', 'при азс лукойл',
#        'лукойл-центрнефть', 'fridays', 'мираторг',
#        'баскин роббинс & стардогс', 'bubbleology', 'starbucks старбакс',
#        'бодрый день кофе с собой', 'boobo', 'паб кружка', 'luciano',
#        'лукойл', 'мята lounge шаболовка', 'f-lounge',
#        'мск    на шаболовке', "домино'с пицца domino,s pizza",
#        'чешская пивная пилзнер', 'beverly hills diner',
#        'кондитерия тирольские', 'lavkalavka', 'хлебница пекарня',
#        'кальян- moskalyan', 'советские времена чебуречная ссср',
#        'мята lounge автозаводская', 'osteria mario', 'мясоroob',
#        'газпромнефтьцентр', 'якитория и спорт', 'goodman гудман',
#        'prime star прайм стар', 'праймстар', 'coffeeshop', 'my box',
#        'vanwok ванwok', 'van wok ванwok', 'бб энд бургерс в&в бургер',
#        'сувлаки', 'суши тун', 'пицца паоло и бенто wok',
#        'starbucks coffee', 'кофемания starbucks', 'movenpick',
#        'fridays kfc', 'marmalato', 'мята lounge октябрьская', 'мята'],
#       dtype=object)

# %% [markdown]
# В результате наших действий, названия общественных заведений, более - менее, были приведены к одному виду. Мы убрали "скрытые" дубликаты в названиях сетевых заведений.

# %% [markdown]
# **Сейчас выделим в отдельный столбец информацию об улице из столбца address.**
# Воспользуемся сайтом MosOpen.ru и выясним какие типы(виды) улиц есть в г.Москва.
#
# Получили:
# 'аллеи, бульвары, деревни, кварталы, линии, микрорайоны, мосты, набережные, парки, переулки, площади, посёлки, проезды, проектируемые проезды, просеки, проспекты, тупики и шоссе'.
#
# Выделять улицы будем с помощью регулярного выражения.

# %% [markdown]
# А именно, воспользуемся строковым методом str.findall, str.extract(). Применим методы к столбцу с адресом, аргументу  передадим регулярное выражение. В результате получим новый столбец  street - названия улицы:

# %%
# Сохраним в переменную pattern рег.выражение для поиска в адресе улицу:
pattern = ',\s?(.*(улица|квартал|деревня|просек|территория|площадь|переулок|бульвар|тупик|шоссе|аллея|набережная\
|микрорайон|линия|проезд|проспект|мост|поселок|посёлок|километр|парк|поселение).*?)?\,'
# Применим методы str.findall и str.extract: сначала найдем улицу, затем сохраним в новый столбец:
df['street'] = df['address'].str.findall(pat = pattern)
df['street'] = df['address'].str.extract(pat = pattern)
# Проверим результат
df.sample(20)
# Out:
#            id                        object_name chain  \
# 7556    20786       закусочная «крошка картошка»    да
# 5665   111780                             пронто    да
# 8625   129754                             сабвей    да
# 13027  199415                           double b   нет
# 11171  178481                          шашлычная   нет
# 12758  194063             савинков игорь юрьевич   нет
# 9443   168377                           мосдонер   нет
# 5340   145397                       кафе при азс   нет
# 7756   149506  бар «фора» (букмекерская контора)   нет
# 11418  188715                               суши   нет
# 1407    20105           кафе «граф монте-кристо»   нет
# 11279  186684                             шаурма   нет
# 4073    28120                  9 автобусный парк   нет
# 2734    29501                  столовая сош 1120   нет
# 665     23906                             дионис   нет
# 14564  217256                         суши store   нет
# 9697   169100                        фреш маркет   нет
# 14987  206594              кальянная noel lounge   нет
# 6971    68443                          изя гриль   нет
# 9860   170541                        донер кебаб   нет
#
#                              object_type  \
# 7556   предприятие быстрого обслуживания
# 5665                                кафе
# 8625   предприятие быстрого обслуживания
# 13027                               кафе
# 11171                               кафе
# 12758                               кафе
# 9443                                кафе
# 5340                                кафе
# 7756                           кафетерий
# 11418  предприятие быстрого обслуживания
# 1407                                кафе
# 11279  предприятие быстрого обслуживания
# 4073                            столовая
# 2734                            столовая
# 665                                 кафе
# 14564                               кафе
# 9697                                кафе
# 14987                                бар
# 6971                                кафе
# 9860   предприятие быстрого обслуживания
#
#                                                  address  number  \
# 7556             город Москва, Бесединское шоссе, дом 15      10
# 5665           город Москва, Вешняковская улица, дом 22А     120
# 8625   город Москва, город Щербинка, Железнодорожная ...       0
# 13027  город Москва, Ленинградское шоссе, дом 16А, ст...      30
# 11171  город Москва, Открытое шоссе, дом 9, строение 14А      16
# 12758  город Москва, улица Сущёвский Вал, дом 5, стро...      45
# 9443          город Москва, Новослободская улица, дом 46      96
# 5340    город Москва, Ярославское шоссе, дом 1, корпус 1      20
# 7756           город Москва, Автозаводская улица, дом 17       0
# 11418           город Москва, Фестивальная улица, дом 2Б      10
# 1407          город Москва, город Зеленоград, корпус 436      40
# 11279         город Москва, Краснодарская улица, дом 57А       2
# 4073         город Москва, 2-й Нагатинский проезд, дом 8      90
# 2734             город Москва, Дубнинская улица, дом 36А     200
# 665            город Москва, улица Миклухо-Маклая, дом 3      45
# 14564           город Москва, проспект Андропова, дом 36       0
# 9697          город Москва, Мосфильмовская улица, дом 2В      10
# 14987  город Москва, Варшавское шоссе, дом 141, корпу...      30
# 6971   город Москва, Сущёвская улица, дом 27, строение 1      48
# 9860                город Москва, улица Чечулина, дом 26       0
#
#               object_name_new                                 street
# 7556          крошка картошка                      Бесединское шоссе
# 5665                   пронто                     Вешняковская улица
# 8625                   subway  город Щербинка, Железнодорожная улица
# 13027                double b                    Ленинградское шоссе
# 11171               шашлычная                         Открытое шоссе
# 12758  савинков игорь юрьевич                    улица Сущёвский Вал
# 9443                 мосдонер                   Новослободская улица
# 5340                  при азс                      Ярославское шоссе
# 7756                     фора                    Автозаводская улица
# 11418                    суши                     Фестивальная улица
# 1407        граф монте-кристо                                    NaN
# 11279                  шаурма                    Краснодарская улица
# 4073        9 автобусный парк                 2-й Нагатинский проезд
# 2734                 сош 1120                       Дубнинская улица
# 665                    дионис                   улица Миклухо-Маклая
# 14564              суши store                     проспект Андропова
# 9697              фреш маркет                   Мосфильмовская улица
# 14987             noel lounge                       Варшавское шоссе
# 6971            изя грilpatio                        Сущёвская улица
# 9860              донер кебаб                         улица Чечулина

# %% [markdown]
# Посмотрим есть ли пропуски в столбцах:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15366 entries, 0 to 15365
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               15366 non-null  int64
#  1   object_name      15366 non-null  object
#  2   chain            15366 non-null  object
#  3   object_type      15366 non-null  object
#  4   address          15366 non-null  object
#  5   number           15366 non-null  int64
#  6   object_name_new  15366 non-null  object
#  7   street           15172 non-null  object
# dtypes: int64(2), object(6)
# memory usage: 960.5+ KB

# %% [markdown]
# В столбце street есть пропуски. Выведем строки с пропусками на экран:

# %%
df[df['street'].isna()].sample(20).values
# Out:
# array([[84460, 'столова «гбоу школа №852»', 'нет', 'столовая',
#         'город Москва, город Зеленоград, корпус 1128', 160,
#         'гбоу школа №852', nan],
#        [29470, 'столовая в школе 1739', 'нет', 'столовая',
#         'город Москва, город Зеленоград, корпус 1555', 180,
#         'в школе 1739', nan],
#        [68113, 'френдс', 'нет', 'кафе',
#         'город Москва, город Зеленоград, корпус 435', 34, 'френдс', nan],
#        [19800, 'набатчиков а.п.', 'нет', 'буфет',
#         'Проектируемый проезд N 5231, дом 8, строение 3', 20,
#         'набатчиков а.п', nan],
#        [173155, 'город-сад', 'нет', 'кафе',
#         'Садовая-Сухаревская улица, дом 2/34, строение 2', 30,
#         'город-сад', nan],
#        [24987, 'шаурма на углях-чайхана баракат', 'нет', 'кафе',
#         'Таганская площадь, дом 88, строение 4', 80,
#         'шаурма на углях-чайхана акат', nan],
#        [29476, 'гбоу г.москвы лицей № 1557', 'нет', 'столовая',
#         'город Москва, город Зеленоград, корпус 529', 160,
#         'гбоу г. лицей № 1557', nan],
#        [29466, 'столовая в школе 1194 корп.1530 (ранее школа1740)',
#         'нет', 'столовая', 'город Москва, город Зеленоград, корпус 1530',
#         180, 'в школе 1194 корп.1530 (ранее школа1740', nan],
#        [144982, 'гудсон бар', 'нет', 'бар',
#         'город Москва, город Зеленоград, корпус 315', 30, 'гудсон', nan],
#        [171555, 'жар птица', 'нет', 'кафе',
#         'Коровинское шоссе, дом 46, корпус 1', 50, 'жар птица', nan],
#        [29410, 'школа 2045 корп.2031', 'нет', 'столовая',
#         'город Москва, город Зеленоград, корпус 2031', 160,
#         'школа 2045 корп.2031', nan],
#        [27564,
#         'государственное бюджетное общеобразовательное учреждение города москвы школа № 1528',
#         'нет', 'столовая', 'город Москва, город Зеленоград, корпус 817',
#         160,
#         'государственное бюджетное общеобразовательное учреждение   школа № 1528',
#         nan],
#        [149863, 'школьно-базовая столовая', 'нет', 'столовая',
#         'Полевая улица, дом 20', 205, 'школьно-базовая', nan],
#        [28214, 'роснефть (закрытое)', 'нет', 'столовая',
#         'Софийская набережная, дом 26/1, строение 1', 80,
#         'роснефть (закрытое', nan],
#        [22982, 'альфорно', 'нет', 'кафе',
#         'город Москва, город Зеленоград, корпус 438', 49, 'альфорно',
#         nan],
#        [84456, 'столовая «гбоу школа №1692»', 'нет', 'столовая',
#         'город Москва, город Зеленоград, корпус 1016', 160,
#         'гбоу школа №1692', nan],
#        [101149, 'кафе «музыкальный клуб форте»', 'нет', 'кафе',
#         'Большая Бронная улица, дом 20/1/27, строение 2', 74,
#         'музыкальный клуб форте', nan],
#        [189558, 'гурман', 'да', 'ресторан', 'Киевская улица, дом 7', 180,
#         'гурман', nan],
#        [29464, 'столовая в школе 1151 корп.1464 (ранее школа 1149)',
#         'нет', 'столовая', 'город Москва, город Зеленоград, корпус 1464',
#         180, 'в школе 1151 корп.1464 (ранее школа 1149', nan],
#        [29471, 'столовая в школе 1194', 'нет', 'столовая',
#         'город Москва, город Зеленоград, корпус 1556', 180,
#         'в школе 1194', nan]], dtype=object)

# %% [markdown]
# Пропуски образовались в результате: 1) в адресе название улицы стоит вначале, а название города отсутствует. А в регулярном выражений вначале стоит запятая;  2) отсутствует название улицы (город присутствует), например, адрес выглядит: 'город Москва, город Зеленоград, корпус 1410', 35'. Заметим, что строк с пропущенными значениями относительно мало по сравнению с общим количеством строк.
#
# Поэтому заменим пропущенные значения на пустую строку. Применим метод fillna():

# %%
df['street'] = df['street'].fillna('')

# %% [markdown]
# ### Вывод:
#
# В результате вышеописанных действий получили столбец 'street', в котором содержится информация о названиях улиц, на которых находятся заведения общественного питания в городе Москва.

# %% [markdown]
# Переходим к анализу данных.
#
# # Анализ данных

# %% [markdown]
# 1. Исследуем соотношение видов объектов общественного питания по количеству. Построим график.
#
# Воспользуемся методом value_counts() и выведем на экран количество каждого типа общественного питания:

# %%
type_count = df['object_type'].value_counts().sort_values(ascending = False).reset_index()
type_count
# Out:
#                                index  object_type
# 0                               кафе         6099
# 1                           столовая         2587
# 2                           ресторан         2285
# 3  предприятие быстрого обслуживания         1923
# 4                                бар          856
# 5                              буфет          585
# 6                          кафетерий          398
# 7                         закусочная          360
# 8          магазин (отдел кулинарии)          273

# %% [markdown]
# Сразу построим график:

# %%
# Выберем стиль для отображение всех графиков в проекте:
plt.style.use('seaborn')
# задаем цветовую гамму:
sns.set_palette('muted')

# %%
# Построим sns.countplot() из библиотеки seaborn:
plt.figure(figsize = (15,10))
sns.countplot(x = 'object_type', data = df, order = type_count['index'])
plt.title('Соотношение видов общественного питания по количеству в г.Москва', pad = 20)
plt.xlabel('Вид общественного питания')
plt.ylabel('Количество')
plt.xticks(rotation='90')
plt.show()

# %% [markdown]
# ### *Вывод:*
#
#
# *В г.Москва больше всех заведений общественного питания с типом 'Кафе': ~6000.*
#
# *С типом: 'Столовая': ~2500,  'Ресторан': ~2200, 'Предприятие быстрого обслуживания': ~1900.*
#
# *С типом: 'Бар': ~850, 'Буфет': ~600,  'Кафетерий' и 'Закусочная': ~400*
#
# *Меньше всех заведений общественного питания с типом 'Отдел кулинарии'(в магазинах): ~300.*

# %% [markdown]
# 2. **Исследуем соотношение сетевых и несетевых заведений по количеству. Построим график.**
#
# Создадим сводную таблицу chain_type: сгруппируем данные по типу заведения и затем посчитаем количество сетевых и несетевых заведений в каждой группе.

# %%
# Создадим сводную таблицу:
chain_type = df.pivot_table(index = 'object_type', 
                            columns = 'chain', 
                            values = 'object_name', 
                            aggfunc = 'count',
                           margins = True)
# Переименуем столбец и строку, содержащие общее количество:
chain_type = chain_type.rename(index = {'All': 'total_amount'}, columns = {'All': 'total_amount'})
# Превратив мульти - индекс в более простой массив:
chain_type.columns = [''.join(x) for x in chain_type.columns.ravel()] 
# Проверим результат:
chain_type
# Out:
#                                      да    нет  total_amount
# object_type
# бар                                  37    819           856
# буфет                                11    574           585
# закусочная                           56    304           360
# кафе                               1396   4703          6099
# кафетерий                            52    346           398
# магазин (отдел кулинарии)            78    195           273
# предприятие быстрого обслуживания   791   1132          1923
# ресторан                            544   1741          2285
# столовая                              3   2584          2587
# total_amount                       2968  12398         15366

# %% [markdown]
# Сейчас построим график:

# %%
# На круговой диаграмме изобразим отношение сетевых и несетевых заведений:

vals = [2968, 12398]
labels = ['Сетевые заведения', 'Несетевые заведения']
textprops = {'fontsize': 15, 'fontweight': 'demi'}
explode = (0, 0.3)
fig , ax = plt.subplots()
ax.pie(vals, labels=labels, autopct='%1.1f%%', pctdistance = 1.3, labeldistance = 1.1\
      , explode=explode, radius = 1.8, wedgeprops={'lw':1,'ls':'--','edgecolor':"k"},\
        textprops = textprops)
plt.title('Соотношение сетевых и несетевых заведений общественного питания в г.Москва', pad = 80, fontsize = 15)

plt.show()

# %% [markdown]
# ### *Вывод:*
#
# *В г.Москва, в основном, заведения общественного питания не являются сетевыми: ~ 80,7%. И только ~ 19,3% - являются сетевыми*
#
# 3. Проверим для какого вида общественного питания характерно сетевое распространение. Построим график:

# %%
plt.figure(figsize = (15,10))
sns.countplot(x = 'object_type', data = df, hue = 'chain', order = type_count['index'])
plt.title('Соотношение сетевых и несетевых заведений по виду общественного питания', pad = 20)
plt.xlabel('Вид общественного питания')
plt.ylabel('Количество')
plt.xticks(rotation='90')
plt.show()

# %% [markdown]
# ### *Вывод*:
#
# *Сетевое распространение характерно для всех типов заведений общественного питания. Но, в основном, для заведений типа: кафе, предприятие быстрого обслуживания, ресторан.*

# %% [markdown]
# 3. Сейчас ответим на вопрос: что характерно для сетевых заведений (много заведений с небольшим числом посадочных мест в каждом или мало заведений с большим количеством посадочных мест)?
#
# Создадим датафрейм df_chain_yes, который будет содержать информацию о всех сетевых заведениях:

# %%
# Отфильтруем строки начальной таблицы df: укажем df['chain'] == 'да':
df_chain_yes = df[df['chain'] == 'да']
df_chain_yes.tail(5)
# Out:
#            id  object_name chain object_type  \
# 15361  208537  шоколадница    да        кафе
# 15362  209264  шоколадница    да        кафе
# 15363  209186  шоколадница    да        кафе
# 15364  221900  шоколадница    да        кафе
# 15365  222535  шоколадница    да        кафе
#
#                                                  address  number  \
# 15361       город Москва, 3-й Крутицкий переулок, дом 18      50
# 15362           город Москва, улица Земляной Вал, дом 33      10
# 15363           город Москва, улица Земляной Вал, дом 33      20
# 15364  город Москва, поселение Московский, Киевское ш...      36
# 15365             город Москва, Ходынский бульвар, дом 4      10
#
#       object_name_new                                             street
# 15361     шоколадница                             3-й Крутицкий переулок
# 15362     шоколадница                                 улица Земляной Вал
# 15363     шоколадница                                 улица Земляной Вал
# 15364     шоколадница  поселение Московский, Киевское шоссе, 22-й кил...
# 15365     шоколадница                                  Ходынский бульвар

# %% [markdown]
# Создадим таблицу col, содержащую информацию о количестве заведений для каждой сети:

# %%
col = df_chain_yes.groupby('object_name_new').agg({'chain' : 'count'}).reset_index()
col.sort_values(by = 'chain', ascending = True).tail(10)
# Out:
#      object_name_new  chain
# 260       папа джонс     66
# 232            милти     79
# 323         суши wok     90
# 211  крошка картошка     96
# 166   домино'с пицца     98
# 337          теремок    109
# 118      бургер кинг    152
# 222       макдоналдс    173
# 32               kfc    178
# 379      шоколадница    183

# %% [markdown]
# Сейчас построим распределение количества заведений для каждой сети:

# %%
plt.figure(figsize = (15,10))
sns.distplot(col['chain'], bins = 24)
plt.title("Распределение количества заведений в сетях")
plt.xlabel('Количество заведений')
plt.show()

# Построим "ящик с усами"
plt.figure(figsize = (15,10))
sns.boxplot(x = 'chain', data = col)
plt.xlim(-2, 20)
plt.title("Распределение количества заведений в сетях")
plt.xlabel('Количество заведений')
plt.show()

# %% [markdown]
# *Распределение данных имеет сильно выраженную положительную ассиметрию. На графике хорошо заметен длинный хвост высоких значений*
#
# *В некоторых сетях количество открытых заведений превышает 100 -150, например: "Макдоналдс" ~172 заведения, "Шоколадница" ~ 183, kfc ~ 177 и др.*
#
# Вычислим 90, 95, 99 перцентиль, медиану и среднее арифметическое для нашего распределения:

# %%
np.percentile(col['chain'], [90, 95, 99])
# Out:
# array([ 13.  ,  32.  , 112.87])

# %%
col.agg({'chain': ['median', 'mean']})
# Out:
#            chain
# median  2.000000
# mean    7.571429

# %% [markdown]
# *Значение медианы ~ 2. Отсюда следует, что в 50% сетей количество заведений не превышает 2.*
#
# *Не более чем в 10% сетей количество заведений превышает 13.*
#
# *Не более 5% сетей имеют количество заведений, превышающих 32 и только в 1% сетей - превышает 115.*

# %% [markdown]
# Выведем на экран названия сетей, в которых количество заведений больше 115:

# %%
argument = np.percentile(col['chain'], 99)
col[col['chain'] > argument]
# Out:
#     object_name_new  chain
# 32              kfc    178
# 118     бургер кинг    152
# 222      макдоналдс    173
# 379     шоколадница    183

# %% [markdown]
# Всеми известные сети: шоколадница, макдоналдс, бургер кинг, kfc.

# %% [markdown]
# Сейчас посмотрим на распределение данных посадочных мест в сетевых заведениях:

# %%
plt.figure(figsize = (15,10))
sns.distplot(df_chain_yes['number'], bins = 70, color = 'darkorange')
plt.title("Распределение посадочных мест в сетевых заведениях")
plt.xlabel('Количество посадочных мест')
plt.show()


# Построим "ящик с усами"
plt.figure(figsize = (15,10))
sns.boxplot(x = 'number', data = df_chain_yes, color = 'darkorange')
plt.xlim(-20, 300)
plt.title("Распределение посадочных мест в сетевых заведениях")
plt.xlabel('Количество посадочных мест')
plt.show()

# %% [markdown]
# *Распределение данных посадочных мест в сетевых заведениях также имеет сильно выраженную положительную ассиметрию: заметен длинный хвост высоких значений.*
#
# *В некоторых заведениях количество посадочных мест превышает 400.*

# %% [markdown]
# Вычислим 90, 95, 99 перцентиль, медиану и среднее арифметическое для нашего распределения:

# %%
np.percentile(df_chain_yes['number'], [90, 95, 99])
# Out:
# array([120.  , 158.65, 275.33])

# %%
df_chain_yes.agg({'number' : ['mean', 'median']})
# Out:
#            number
# mean    52.919811
# median  40.000000

# %% [markdown]
# *В 50% заведений число посадочных мест не превышает 40. В остальных 50% число посадочных мест не меньше 40.*
#
# *Не более 10% заведений имеют число посадочных мест больше 120.*
#
# *Не более 5% заведений имеют число посадочных мест больше 160.*
#
# *И только не более 1% заведений - больше 280.*

# %% [markdown]
# ### *Вывод:*
#
# *Из всего вышесказанного следует, что для сетевых заведений характерно: много заведений с относительно небольшим числом посадочных мест в каждом.*
#
# *Думаю, что число посадочных мест для конкретного заведения зависит еще и от места, в котором оно расположено.*

# %% [markdown]
# Для сетей общественного питания характерно наличие нескольких заведений в конкретном городе, стране, мире. Например, "Бургер Кинг", "Макдоналдс", "KFC" - крупные сети. Их бренд знают во всем мире.
#
# Разделим сети Москвы на две группы:
#
# - крупные с раскрученным брендом;
#
# - мелкие, развивающиеся сети.
#
# Количество заведений в мелких развивающихся сетях в Москве: от 2 до 13.
#
# Количество заведений в крупных сетях с раскрученным брендом составляет от 13 и выше.
#
# Выведем на экран таблицу с названием бренда сети и количеством заведений в каждой:

# %%
argument_1 = np.percentile(col['chain'], 90)
seti = col[col['chain'] >= argument_1].sort_values(by = 'chain', ascending = False)
seti = seti.rename(columns = ({'object_name_new': 'object_name', 'chain': 'object_count'}))
seti
# Out:
#             object_name  object_count
# 379         шоколадница           183
# 32                  kfc           178
# 222          макдоналдс           173
# 118         бургер кинг           152
# 337             теремок           109
# 166      домино'с пицца            98
# 211     крошка картошка            96
# 323            суши wok            90
# 232               милти            79
# 260          папа джонс            66
# 59               subway            58
# 164          додо пицца            54
# 368          чайхона №1            49
# 385            якитория            48
# 332              тануки            47
# 196        кофе с собой            46
# 358          хинкальная            43
# 199           кофе хаус            38
# 362       хлеб насущный            33
# 53            starbucks            32
# 240               му-му            32
# 28        ilpatio патио            31
# 244         мята lounge            30
# 93             андерсон            29
# 287          прайм стар            28
# 311            старбакс            27
# 10                cofix            25
# 276           пицца хат            24
# 112  братьев караваевых            19
# 383              штолле            19
# 212              кружка            18
# 285               прайм            17
# 328             сушишоп            17
# 272         пицца паоло            16
# 204           кофемания            16
# 314            стардогs            15
# 324            суши сет            15
# 89           алло пицца            15
# 98       баскин роббинс            14
# 127           ваби-саби            13
# 136          волконский            13
# 162          джон джоли            13

# %% [markdown]
# Например, в г.Москва сеть "Шоколадница" имеет 183 заведения, "KFC" - 178, "Макдоналдс" - 173, "Бургер Кинг" - 152 и т.д. Чем более узнаваемый бренд у сети, тем больше заведений имеет в Москве.

# %% [markdown]
# Медианное количество посадочных мест в сетевых заведениях: ~40. То есть:
#
# В 50% всех заведений количество посадочных мест лежит в диапазоне от 0 до 40.
#
# В остальных 50% заведениях: количество посадочных мест составляет:  40 - 300.

# %% [markdown]
# 4.	Для каждого вида объекта общественного питания опишем среднее количество посадочных мест. И ответим на вопрос:
# какой вид предоставляет в среднем самое большое количество посадочных мест? Построим графики.
#
# Сразу перейдем к построению графика: "ящика с усами" и диаграммы рассеяния для каждого вида данных(stripplot()):

# %%
plt.figure(figsize = (15,10))
sns.boxplot(y = 'object_type', x = 'number', data = df)
plt.title('Количество посадочных мест для каждого вида общественного питания', pad = 20)
plt.ylabel('Вид общественного питания')
plt.xlabel('Количество')
plt.xlim(-10,600)
plt.show()

plt.figure(figsize = (15,10))
sns.stripplot(y = 'object_type', x = 'number', data = df, alpha = 0.25)
plt.title('Количество посадочных мест для каждого вида общественного питания', pad = 20)
plt.ylabel('Вид общественного питания')
plt.xlabel('Количество')
plt.xlim(-10,600)
plt.show()

# %% [markdown]
# Выведем таблицу со значением медианы и среднего арифметического для каждого типа заведения:

# %%
number_mean = round(df.groupby('object_type').agg({'number': ['mean', 'median']}), 0)
number_mean.T
# Out:
# object_type     бар  буфет  закусочная  кафе  кафетерий  \
# number mean    43.0   51.0         8.0  40.0        9.0
#        median  35.0   32.0         0.0  30.0        6.0
#
# object_type    магазин (отдел кулинарии)  предприятие быстрого обслуживания  \
# number mean                          6.0                               21.0
#        median                        0.0                                5.0
#
# object_type    ресторан  столовая
# number mean        97.0     130.0
#        median      80.0     103.0

# %% [markdown]
# Также вычислим перцентили: 90, 95, 99:

# %%
# Нужно фильтровать данные, подставляя нужный тип:
r = df[df['object_type'] == 'столовая'].copy()
np.percentile(r['number'], [90,95,99])
# Out:
# array([240. , 289.4, 330. ])

# %% [markdown]
# ### *Вывод:*
#
# *Все распределения данных имеют положительную ассиметрию: перекос вправо. Что говорит о наличии длинного хвоста высоких значений. Возможно есть выбросы.*
#
# *КАФЕ: среднее количество посадочных мест ~30. Для 95% заведений число не превышает 100. И лишь для 1% число мест превышает 190.*
#
# *СТОЛОВАЯ: среднее количество посадочных мест ~103. Для 95% заведений число не превышает 300. И лишь для 1% число мест превышает 330.*
#
# *ЗАКУСОЧНАЯ: 50% заведений не имеют посадочных мест. Остальные 50% имеют  небольшое количество. Не более в 10% число мест превышает 22. Не более в 5% - превышает 35.И лишь для 1% число мест превышает 60.*
#
# *ПРЕДПРИЯТИЕ БЫСТРОГО ОБСЛУЖИВАНИЯ: среднее количество посадочных мест ~5.  Не более в 10% число мест превышает 60. Не более в 5% - превышает 92.И лишь для 1% число мест превышает 170.*
#
# *РЕСТОРАН: среднее количество посадочных мест ~80.  Не более в 10% число мест превышает 180. Не более в 5% - превышает 250.И лишь для 1% число мест превышает 500.*
#
# *КАФЕТЕРИЙ: среднее количество посадочных мест ~6.  Не более в 10% число мест превышает 21. Не более в 5% - превышает 30.И лишь для 1% число мест превышает 50.*
#
# *БУФЕТ: среднее количество посадочных мест ~32.  Не более в 10% число мест превышает 120. Не более в 5% - превышает 170. И лишь для 1% число мест превышает 250.*
#
# *БАР: среднее количество посадочных мест ~35.  Не более в 10% число мест превышает 85. Не более в 5% - превышает 100. И лишь для 1% число мест превышает 180.*
#
# *МАГАЗИН(ОТДЕЛ КУЛИНАРИИ): 50% заведений не имеют посадочных мест. Остальные 50% имеют  небольшое количество.  Не более в 10% число мест превышает 15. Не более в 5% - превышает 30. И лишь для 1% число мест превышает 40.*
#
# *Итак, самое большое число посадочных мест предоставляет заведение общественного питания с типом: столовая.*

# %% [markdown]
# 5.	Построим график топ-10 улиц по количеству объектов общественного питания. Воспользуемся внешней информацией и ответим на вопрос — в каких районах Москвы находятся эти улицы?
#
# Выведем на экран таблицу с данными df (информация о заведениях):

# %%
df.head(5)
# Out:
#        id             object_name chain object_type  \
# 0  151635                 сметана   нет        кафе
# 1   77874                  родник   нет        кафе
# 2   24309         кафе «академия»   нет        кафе
# 3   21894              пиццетория    да        кафе
# 4  119365  кафе «вишневая метель»   нет        кафе
#
#                                              address  number  object_name_new  \
# 0         город Москва, улица Егора Абакумова, дом 9      48          сметана
# 1  город Москва, улица Талалихина, дом 2/1, корпус 1      35           родник
# 2          город Москва, Абельмановская улица, дом 6      95         академия
# 3            город Москва, Абрамцевская улица, дом 1      40       пиццетория
# 4  город Москва, Абрамцевская улица, дом 9, корпус 1      50  вишневая метель
#
#                   street
# 0  улица Егора Абакумова
# 1       улица Талалихина
# 2   Абельмановская улица
# 3     Абрамцевская улица
# 4     Абрамцевская улица

# %% [markdown]
# Сформируем таблицу "Топ-10 улиц г.Москва по количеству общественного питания"

# %%
street_table = df[df['street'] != ''].groupby('street').agg({'object_name': 'count'})\
                                     .sort_values(by = 'object_name', ascending = False).reset_index()
street_table_result = street_table.loc[0:9]
street_table_result.sort_values(by = 'object_name', ascending = True)
# Out:
#                    street  object_name
# 9    Кировоградская улица          110
# 8         Каширское шоссе          112
# 7    Кутузовский проспект          114
# 6    проспект Вернадского          132
# 5      Ленинский проспект          147
# 4        Варшавское шоссе          161
# 3  Пресненская набережная          167
# 2  Ленинградский проспект          171
# 1       Профсоюзная улица          182
# 0           проспект Мира          204

# %% [markdown]
# *Больше всех заведений общественного питания в г.Москва расположено на ул.Проспект Мира: ~ 200.*
#
# *А также Профсоюзной :~180, на Ленинградском проспекте: ~170.*
#
# *Скорее всего данные улицы имеют большую протяженность.*
#
# Выясним в каких районах г.Москвы расположены данные улицы.

# %% [markdown]
# Обратимся к внешней информации, а именно к сайту [OpenStreetMap](https://www.openstreetmap.org/)
#
# Создадим функцию, которая будет отправлять запрос на указанный выше сайт и сохранять в словарь название района.
#
# Для того, чтобы понять какого вида должен быть запрос, зайдем на сайт в панель разработчика(F12)\вкладка network. Далее на сайте введем адрес в поле для поиска. Нас интересует GET - запрос.
#
# В результате GET - запрос должен быть вида: 'https://www.openstreetmap.org/geocoder/search_osm_nominatim?query=адрес'
#
# После вопросительного знака изменяемая часть, т.е. если мы будем передавать в query наш адрес, мы будем получать нужную нам информацию.
#
# Для того, чтобы нам сохранить название района воспользуемся возможностями библиотеки BeautifulSoup и вкладкой ELEMENTS на сайте в панели разработчика.
#
# В результате: нужная нам информация содержится в теге <a 'class': 'set_position'>.

# %% [markdown]
# И еще, передаваемая информация должна иметь вид: например, Москва, проспект Мира. Поэтому преобразуем данные в столбце street в street_table: добавим название города:

# %%
street_table_result['street'] = "Москва, " + street_table_result['street']
street_table_result
# Out:
# C:\Users\PPC\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                            street  object_name
# 0           Москва, проспект Мира          204
# 1       Москва, Профсоюзная улица          182
# 2  Москва, Ленинградский проспект          171
# 3  Москва, Пресненская набережная          167
# 4        Москва, Варшавское шоссе          161
# 5      Москва, Ленинский проспект          147
# 6    Москва, проспект Вернадского          132
# 7    Москва, Кутузовский проспект          114
# 8         Москва, Каширское шоссе          112
# 9    Москва, Кировоградская улица          110

# %%
# Подключим библиотеки:
import requests
from bs4 import BeautifulSoup
content = [] # создаем пустой список
query = street_table_result['street'] # передаем query столбец
    # создаем цикл: перебираем нужные нам адреса:
for i in query:
        # сохраняем get запрос в переменную response; адрес i будем передавать в query={}.format(i)
        response = requests.get('https://www.openstreetmap.org/geocoder/search_osm_nominatim?query={}'.format(i))
        # к тексту ответа запроса применим парсер 'lxml', создав дерево сайта с помощью BeautifulSoup:
        soup = BeautifulSoup(response.text, 'lxml')
        # находим нужную нам информацию
        table = soup.find_all('a', attrs = {'class': 'set_position'})
        # сохраняем текст в список:
        for y in soup.find_all('a', attrs = {'class': 'set_position'}):
            content.append(y.text)

# %% [markdown]
# Сохраняем полученную информацию в датафрейм:

# %%
new_top = pd.DataFrame()
new_top['content'] = content
new_top['content'].values
# Out:
# array(['Проспект Мира, улица Гиляровского, Мещанский район, Центральный административный округ, Москва, Центральный федеральный округ, 129090, Россия',
#        'проспект Мира, Мещанский район, Центральный административный округ, Москва, Центральный федеральный округ, 129010, Россия',
#        'проспект Мира, Мещанский район, Центральный административный округ, Москва, Центральный федеральный округ, 129090, Россия',
#        'проспект Мира, Мещанский район, Центральный административный округ, Москва, Центральный федеральный округ, 129110, Россия',
#        'Москва, 19/21, проспект Мира, Центральный район, Калининград, городской округ Калининград, Калининградская область, Северо-Западный федеральный округ, 236036, Россия',
#        'Москва, проспект Мира, 2-й микрорайон, Кирово-Чепецк, городской округ Кирово-Чепецк, Кировская область, Приволжский федеральный округ, 613045, Россия',
#        'Профсоюзная улица, Знамя Октября, городской округ Подольск, Новомосковский административный округ, Москва, Центральный федеральный округ, 142134, Россия',
#        'Профсоюзная улица, район Ясенево, Юго-Западный административный округ, Москва, Центральный федеральный округ, 117465, Россия',
#        'Профсоюзная улица, Коньково, район Коньково, Юго-Западный административный округ, Москва, Центральный федеральный округ, 117632, Россия',
#        'Профсоюзная улица, Коньково, район Коньково, Юго-Западный административный округ, Москва, Центральный федеральный округ, 117647, Россия',
#        'Профсоюзная улица, район Тёплый Стан, Юго-Западный административный округ, Москва, Центральный федеральный округ, 117465, Россия',
#        'Профсоюзная улица, район Тёплый Стан, Юго-Западный административный округ, Москва, Центральный федеральный округ, 117632, Россия',
#        'Профсоюзная улица, район Ясенево, Юго-Западный административный округ, Москва, Центральный федеральный округ, 117632, Россия',
#        'Профсоюзная улица, район Ясенево, Юго-Западный административный округ, Москва, Центральный федеральный округ, 117632, Россия',
#        'Профсоюзная улица, район Ясенево, Юго-Западный административный округ, Москва, Центральный федеральный округ, 117465, Россия',
#        'Профсоюзная улица, район Тёплый Стан, Юго-Западный административный округ, Москва, Центральный федеральный округ, 117465, Россия',
#        'Ленинградский проспект, посёлок Сокол, район Сокол, Москва, Северный административный округ, Москва, Центральный федеральный округ, 125057, Россия',
#        'Ленинградский проспект, Аэропорт, район Аэропорт, Северный административный округ, Москва, Центральный федеральный округ, 125167, Россия',
#        'Ленинградский проспект, Аэропорт, район Аэропорт, Северный административный округ, Москва, Центральный федеральный округ, 125190, Россия',
#        'Ленинградский проспект, Аэропорт, район Аэропорт, Северный административный округ, Москва, Центральный федеральный округ, 125167, Россия',
#        'Ленинградский проспект, Аэропорт, район Аэропорт, Северный административный округ, Москва, Центральный федеральный округ, 125190, Россия',
#        'Ленинградский проспект, Аэропорт, район Аэропорт, Северный административный округ, Москва, Центральный федеральный округ, 125319, Россия',
#        'Ленинградский проспект, район Беговой, Северный административный округ, Москва, Центральный федеральный округ, 125167, Россия',
#        'Ленинградский проспект, Хорошёвский район, Северный административный округ, Москва, Центральный федеральный округ, 125167, Россия',
#        'Ленинградский проспект, район Аэропорт, Северный административный округ, Москва, Центральный федеральный округ, 125167, Россия',
#        'Ленинградский проспект, Хорошёвский район, Северный административный округ, Москва, Центральный федеральный округ, 125167, Россия',
#        'Пресненская набережная, Пресненский район, Центральный административный округ, Москва, Центральный федеральный округ, 123317, Россия',
#        'Пресненская набережная, Камушки, Пресненский район, Центральный административный округ, Москва, Центральный федеральный округ, 123317, Россия',
#        'Пресненская набережная, Пресненский район, Центральный административный округ, Москва, Центральный федеральный округ, 123112, Россия',
#        'Варшавское шоссе, Бутово, район Южное Бутово, Юго-Западный административный округ, Москва, Центральный федеральный округ, 142002, Россия',
#        'Варшавское шоссе, Бутово, район Южное Бутово, Юго-Западный административный округ, Москва, Центральный федеральный округ, 142720, Россия',
#        'Варшавское шоссе, район Южное Бутово, Юго-Западный административный округ, Москва, Центральный федеральный округ, 142720, Россия',
#        'Варшавское шоссе, район Южное Бутово, Юго-Западный административный округ, Москва, Центральный федеральный округ, 117623, Россия',
#        'Симферопольское шоссе, городской округ Щербинка, Новомосковский административный округ, Москва, Центральный федеральный округ, 114178, Россия',
#        'Симферопольское шоссе, Барыши, городской округ Щербинка, Новомосковский административный округ, Москва, Центральный федеральный округ, 114178, Россия',
#        'Симферопольское шоссе, городской округ Щербинка, Новомосковский административный округ, Москва, Центральный федеральный округ, 142171, Россия',
#        'Ленинский проспект, Третье Транспортное кольцо, Донской, Донской район, Южный административный округ, Москва, Центральный федеральный округ, 119334, Россия',
#        'Ленинский проспект, Обручевский, Обручевский район, Юго-Западный административный округ, Москва, Центральный федеральный округ, 119421, Россия',
#        'Ленинский проспект, Ломоносовский, Ломоносовский район, Юго-Западный административный округ, Москва, Центральный федеральный округ, 119313, Россия',
#        'Ленинский проспект, Ломоносовский, Ломоносовский район, Юго-Западный административный округ, Москва, Центральный федеральный округ, 119261, Россия',
#        'Ленинский проспект, Тропарёво, Западный административный округ, Москва, Центральный федеральный округ, 117198, Россия',
#        'Ленинский проспект, Тропарёво, Западный административный округ, Москва, Центральный федеральный округ, 117513, Россия',
#        'Ленинский проспект, район Тёплый Стан, Юго-Западный административный округ, Москва, Центральный федеральный округ, 117513, Россия',
#        'Ленинский проспект, Ломоносовский район, Юго-Западный административный округ, Москва, Центральный федеральный округ, 119331, Россия',
#        'Ленинский проспект, район Проспект Вернадского, Западный административный округ, Москва, Центральный федеральный округ, 119421, Россия',
#        'Ленинский проспект, район Проспект Вернадского, Западный административный округ, Москва, Центральный федеральный округ, 119331, Россия',
#        'Проспект Вернадского, улица Удальцова, Проспект Вернадского, район Проспект Вернадского, Западный административный округ, Москва, Центральный федеральный округ, 119415, Россия',
#        'проспект Вернадского, Воробьёвы Горы, район Раменки, Западный административный округ, Москва, Центральный федеральный округ, 119333, Россия',
#        'проспект Вернадского, Тропарёво, Западный административный округ, Москва, Центральный федеральный округ, 117571, Россия',
#        'проспект Вернадского, Тропарёво, Западный административный округ, Москва, Центральный федеральный округ, 119571, Россия',
#        'проспект Вернадского, Проспект Вернадского, район Проспект Вернадского, Западный административный округ, Москва, Центральный федеральный округ, 119415, Россия',
#        'проспект Вернадского, Гагаринский район, Юго-Западный административный округ, Москва, Центральный федеральный округ, 119311, Россия',
#        'проспект Вернадского, Тропарёво-Никулино, Западный административный округ, Москва, Центральный федеральный округ, 119571, Россия',
#        'проспект Вернадского, Гагаринский, Гагаринский район, Юго-Западный административный округ, Москва, Центральный федеральный округ, 119333, Россия',
#        'Проспект Вернадского, Москва, Западный административный округ, Москва, Центральный федеральный округ, 119415, Россия',
#        'Кутузовский проспект, Дорогомилово, район Дорогомилово, Западный административный округ, Москва, Центральный федеральный округ, 121151, Россия',
#        'Кутузовский проспект, Дорогомилово, район Дорогомилово, Западный административный округ, Москва, Центральный федеральный округ, 121165, Россия',
#        'Кутузовский проспект, Дорогомилово, район Дорогомилово, Западный административный округ, Москва, Центральный федеральный округ, УЛИЦА МОЖАЙСКИЙ ВАЛ, Россия',
#        'Кутузовский проспект, Дорогомилово, район Дорогомилово, Западный административный округ, Москва, Центральный федеральный округ, 119136, Россия',
#        'Кутузовский проспект, Дорогомилово, район Дорогомилово, Западный административный округ, Москва, Центральный федеральный округ, 121170, Россия',
#        'Каширское шоссе, район Москворечье-Сабурово, Южный административный округ, Москва, Центральный федеральный округ, 115446, Россия',
#        'Каширское шоссе, район Москворечье-Сабурово, Южный административный округ, Москва, Центральный федеральный округ, 115304, Россия',
#        'Каширское шоссе, район Москворечье-Сабурово, Южный административный округ, Москва, Центральный федеральный округ, 115522, Россия',
#        'Каширское шоссе, район Москворечье-Сабурово, Южный административный округ, Москва, Центральный федеральный округ, 115478, Россия',
#        'Каширское шоссе, Нагатино-Садовники, район Нагатино-Садовники, Южный административный округ, Москва, Центральный федеральный округ, 115230, Россия',
#        'Каширское шоссе, Нагатино-Садовники, район Нагатино-Садовники, Южный административный округ, Москва, Центральный федеральный округ, 115478, Россия',
#        'Каширское шоссе, Орехово-Борисово Южное, район Орехово-Борисово Южное, Южный административный округ, Москва, Центральный федеральный округ, 115582, Россия',
#        'Каширское шоссе, Нагорный, Нагорный район, Южный административный округ, Москва, Центральный федеральный округ, 115230, Россия',
#        'Каширское шоссе, Орехово-Борисово, район Орехово-Борисово Северное, Южный административный округ, Москва, Центральный федеральный округ, 115446, Россия',
#        'Каширское шоссе, район Нагатино-Садовники, Южный административный округ, Москва, Центральный федеральный округ, 115230, Россия',
#        'Кировоградская улица, район Чертаново Центральное, Южный административный округ, Москва, Центральный федеральный округ, 117519, Россия',
#        'Кировоградская улица, район Чертаново Южное, Южный административный округ, Москва, Центральный федеральный округ, 117534, Россия',
#        'Кировоградская улица, район Чертаново Центральное, Южный административный округ, Москва, Центральный федеральный округ, 117534, Россия',
#        'Кировоградская улица, Чертаново Северное, район Чертаново Северное, Южный административный округ, Москва, Центральный федеральный округ, 113587, Россия',
#        'Кировоградская улица, район Чертаново Центральное, Южный административный округ, Москва, Центральный федеральный округ, 113587, Россия'],
#       dtype=object)

# %% [markdown]
# Создадим в датафрейме new_top столбец area, который будет содержать информацию о районе.
#
# Название района из данных столбца 'content' будем извлекать с помощью регулярного выражения. И с помощью строковых методов str.findall() и str.extract():

# %%
# Пишем рег.выражение, которое сохраняем в переменную pattern:
pattern = ',\ ([\w\-\w]+ район|район [\w\-\w\s\w]+)\,'
new_top['area'] = new_top['content'].str.findall(pat = pattern)
new_top['area'] = new_top['content'].str.extract(pat = pattern)
new_top.sample(20)
# Out:
#                                               content  \
# 39  Ленинский проспект, Ломоносовский, Ломоносовск...
# 72  Кировоградская улица, район Чертаново Централь...
# 69  Каширское шоссе, район Нагатино-Садовники, Южн...
# 27  Пресненская набережная, Камушки, Пресненский р...
# 0   Проспект Мира, улица Гиляровского, Мещанский р...
# 9   Профсоюзная улица, Коньково, район Коньково, Ю...
# 70  Кировоградская улица, район Чертаново Централь...
# 13  Профсоюзная улица, район Ясенево, Юго-Западный...
# 28  Пресненская набережная, Пресненский район, Цен...
# 20  Ленинградский проспект, Аэропорт, район Аэропо...
# 3   проспект Мира, Мещанский район, Центральный ад...
# 17  Ленинградский проспект, Аэропорт, район Аэропо...
# 62  Каширское шоссе, район Москворечье-Сабурово, Ю...
# 1   проспект Мира, Мещанский район, Центральный ад...
# 4   Москва, 19/21, проспект Мира, Центральный райо...
# 35  Симферопольское шоссе, городской округ Щербинк...
# 41  Ленинский проспект, Тропарёво, Западный админи...
# 47  проспект Вернадского, Воробьёвы Горы, район Ра...
# 40  Ленинский проспект, Тропарёво, Западный админи...
# 7   Профсоюзная улица, район Ясенево, Юго-Западный...
#
#                            area
# 39          Ломоносовский район
# 72  район Чертаново Центральное
# 69     район Нагатино-Садовники
# 27            Пресненский район
# 0               Мещанский район
# 9                район Коньково
# 70  район Чертаново Центральное
# 13                район Ясенево
# 28            Пресненский район
# 20               район Аэропорт
# 3               Мещанский район
# 17               район Аэропорт
# 62   район Москворечье-Сабурово
# 1               Мещанский район
# 4             Центральный район
# 35                          NaN
# 41                          NaN
# 47                район Раменки
# 40                          NaN
# 7                 район Ясенево

# %% [markdown]
# В столбце, содержащий название района есть пропущенные значения. Выведем их на экран:

# %%
new_top[new_top['area'].isna()].sort_values(by ='content').values
# Out:
# array([['Ленинский проспект, Тропарёво, Западный административный округ, Москва, Центральный федеральный округ, 117198, Россия',
#         nan],
#        ['Ленинский проспект, Тропарёво, Западный административный округ, Москва, Центральный федеральный округ, 117513, Россия',
#         nan],
#        ['Москва, проспект Мира, 2-й микрорайон, Кирово-Чепецк, городской округ Кирово-Чепецк, Кировская область, Приволжский федеральный округ, 613045, Россия',
#         nan],
#        ['Проспект Вернадского, Москва, Западный административный округ, Москва, Центральный федеральный округ, 119415, Россия',
#         nan],
#        ['Профсоюзная улица, Знамя Октября, городской округ Подольск, Новомосковский административный округ, Москва, Центральный федеральный округ, 142134, Россия',
#         nan],
#        ['Симферопольское шоссе, Барыши, городской округ Щербинка, Новомосковский административный округ, Москва, Центральный федеральный округ, 114178, Россия',
#         nan],
#        ['Симферопольское шоссе, городской округ Щербинка, Новомосковский административный округ, Москва, Центральный федеральный округ, 114178, Россия',
#         nan],
#        ['Симферопольское шоссе, городской округ Щербинка, Новомосковский административный округ, Москва, Центральный федеральный округ, 142171, Россия',
#         nan],
#        ['проспект Вернадского, Тропарёво, Западный административный округ, Москва, Центральный федеральный округ, 117571, Россия',
#         nan],
#        ['проспект Вернадского, Тропарёво, Западный административный округ, Москва, Центральный федеральный округ, 119571, Россия',
#         nan],
#        ['проспект Вернадского, Тропарёво-Никулино, Западный административный округ, Москва, Центральный федеральный округ, 119571, Россия',
#         nan]], dtype=object)

# %% [markdown]
# В полученном контенте не оказалось названия района. Также попала информация, не относящая к г.Москва. Поэтому данные строки не будем брать во внимание в дальнейшей работе.

# %% [markdown]
# Добавим название округа:

# %%
# Создаем новый столбец, с помощью str.findall находим нужный фрагмент текста
# Затем с помощью str.extract создаем строку из нужного фрагмента
pattern = ',\ ([\w+\-\w+]* административный округ|Московская область)\,'
new_top['okrug'] = new_top['content'].str.findall(pat = pattern)
new_top['okrug'] = new_top['content'].str.extract(pat = pattern)
new_top.sample(20)
# Out:
#                                               content  \
# 53  проспект Вернадского, Гагаринский, Гагаринский...
# 56  Кутузовский проспект, Дорогомилово, район Доро...
# 72  Кировоградская улица, район Чертаново Централь...
# 58  Кутузовский проспект, Дорогомилово, район Доро...
# 11  Профсоюзная улица, район Тёплый Стан, Юго-Запа...
# 74  Кировоградская улица, район Чертаново Централь...
# 49  проспект Вернадского, Тропарёво, Западный адми...
# 65  Каширское шоссе, Нагатино-Садовники, район Наг...
# 6   Профсоюзная улица, Знамя Октября, городской ок...
# 52  проспект Вернадского, Тропарёво-Никулино, Запа...
# 47  проспект Вернадского, Воробьёвы Горы, район Ра...
# 26  Пресненская набережная, Пресненский район, Цен...
# 50  проспект Вернадского, Проспект Вернадского, ра...
# 2   проспект Мира, Мещанский район, Центральный ад...
# 33  Симферопольское шоссе, городской округ Щербинк...
# 73  Кировоградская улица, Чертаново Северное, райо...
# 46  Проспект Вернадского, улица Удальцова, Проспек...
# 16  Ленинградский проспект, посёлок Сокол, район С...
# 35  Симферопольское шоссе, городской округ Щербинк...
# 15  Профсоюзная улица, район Тёплый Стан, Юго-Запа...
#
#                            area                                  okrug
# 53            Гагаринский район    Юго-Западный административный округ
# 56           район Дорогомилово        Западный административный округ
# 72  район Чертаново Центральное           Южный административный округ
# 58           район Дорогомилово        Западный административный округ
# 11            район Тёплый Стан    Юго-Западный административный округ
# 74  район Чертаново Центральное           Южный административный округ
# 49                          NaN        Западный административный округ
# 65     район Нагатино-Садовники           Южный административный округ
# 6                           NaN  Новомосковский административный округ
# 52                          NaN        Западный административный округ
# 47                район Раменки        Западный административный округ
# 26            Пресненский район     Центральный административный округ
# 50   район Проспект Вернадского        Западный административный округ
# 2               Мещанский район     Центральный административный округ
# 33                          NaN  Новомосковский административный округ
# 73     район Чертаново Северное           Южный административный округ
# 46   район Проспект Вернадского        Западный административный округ
# 16                  район Сокол        Северный административный округ
# 35                          NaN  Новомосковский административный округ
# 15            район Тёплый Стан    Юго-Западный административный округ

# %%
# Исключаем из датафрейма new_top строки с пропущенными значениями:
new_top = new_top[~new_top['area'].isna()].sort_values(by ='content')
# В столбце content оставляем только название улицы:
# Используем метод str.split('\,') и берем только индекс str[0] и перезаписываем данные в столбце:
new_top['content'] = new_top['content'].str.split('\,').str[0]
new_top.head(20)
# Out:
#                  content                             area  \
# 29      Варшавское шоссе               район Южное Бутово
# 30      Варшавское шоссе               район Южное Бутово
# 32      Варшавское шоссе               район Южное Бутово
# 31      Варшавское шоссе               район Южное Бутово
# 64       Каширское шоссе         район Нагатино-Садовники
# 65       Каширское шоссе         район Нагатино-Садовники
# 67       Каширское шоссе                   Нагорный район
# 66       Каширское шоссе     район Орехово-Борисово Южное
# 68       Каширское шоссе  район Орехово-Борисово Северное
# 61       Каширское шоссе       район Москворечье-Сабурово
# 60       Каширское шоссе       район Москворечье-Сабурово
# 63       Каширское шоссе       район Москворечье-Сабурово
# 62       Каширское шоссе       район Москворечье-Сабурово
# 69       Каширское шоссе         район Нагатино-Садовники
# 73  Кировоградская улица         район Чертаново Северное
# 74  Кировоградская улица      район Чертаново Центральное
# 70  Кировоградская улица      район Чертаново Центральное
# 72  Кировоградская улица      район Чертаново Центральное
# 71  Кировоградская улица            район Чертаново Южное
# 58  Кутузовский проспект               район Дорогомилово
#
#                                   okrug
# 29  Юго-Западный административный округ
# 30  Юго-Западный административный округ
# 32  Юго-Западный административный округ
# 31  Юго-Западный административный округ
# 64         Южный административный округ
# 65         Южный административный округ
# 67         Южный административный округ
# 66         Южный административный округ
# 68         Южный административный округ
# 61         Южный административный округ
# 60         Южный административный округ
# 63         Южный административный округ
# 62         Южный административный округ
# 69         Южный административный округ
# 73         Южный административный округ
# 74         Южный административный округ
# 70         Южный административный округ
# 72         Южный административный округ
# 71         Южный административный округ
# 58      Западный административный округ

# %% [markdown]
# Преобразуем текст в датафрейме new_top к одному виду: приведем к нижнему регистру

# %%
# Приводим к нижнему регистру:
new_top['content'] = new_top['content'].str.lower()
new_top['area'] = new_top['area'].str.lower()
new_top['okrug'] = new_top['okrug'].str.lower()
new_top
# Out:
#                  content                        area  \
# 29      варшавское шоссе          район южное бутово
# 30      варшавское шоссе          район южное бутово
# 32      варшавское шоссе          район южное бутово
# 31      варшавское шоссе          район южное бутово
# 64       каширское шоссе    район нагатино-садовники
# ..                   ...                         ...
# 53  проспект вернадского           гагаринский район
# 50  проспект вернадского  район проспект вернадского
# 1          проспект мира             мещанский район
# 2          проспект мира             мещанский район
# 3          проспект мира             мещанский район
#
#                                   okrug
# 29  юго-западный административный округ
# 30  юго-западный административный округ
# 32  юго-западный административный округ
# 31  юго-западный административный округ
# 64         южный административный округ
# ..                                  ...
# 53  юго-западный административный округ
# 50      западный административный округ
# 1    центральный административный округ
# 2    центральный административный округ
# 3    центральный административный округ
#
# [64 rows x 3 columns]

# %% [markdown]
# Удалим в датафрейме дубликаты:

# %%
# Удаляем дубликаты:
new_top = new_top.drop_duplicates().reset_index(drop = True)
# Исключаем образовавшиеся пропуски:
new_top[~new_top['okrug'].isna()].sort_values(by='content')
# Out:
#                    content                             area  \
# 0         варшавское шоссе               район южное бутово
# 1          каширское шоссе         район нагатино-садовники
# 2          каширское шоссе                   нагорный район
# 3          каширское шоссе     район орехово-борисово южное
# 4          каширское шоссе  район орехово-борисово северное
# 5          каширское шоссе       район москворечье-сабурово
# 6     кировоградская улица         район чертаново северное
# 7     кировоградская улица      район чертаново центральное
# 8     кировоградская улица            район чертаново южное
# 9     кутузовский проспект               район дорогомилово
# 12  ленинградский проспект                      район сокол
# 13  ленинградский проспект                    район беговой
# 10  ленинградский проспект                   район аэропорт
# 11  ленинградский проспект                хорошёвский район
# 14      ленинский проспект              ломоносовский район
# 15      ленинский проспект                обручевский район
# 16      ленинский проспект                    донской район
# 17      ленинский проспект       район проспект вернадского
# 18      ленинский проспект                район тёплый стан
# 20  пресненская набережная                пресненский район
# 26    проспект вернадского                    район раменки
# 21    проспект вернадского       район проспект вернадского
# 27    проспект вернадского                гагаринский район
# 22           проспект мира                  мещанский район
# 23       профсоюзная улица                   район коньково
# 24       профсоюзная улица                район тёплый стан
# 25       профсоюзная улица                    район ясенево
#
#                                   okrug
# 0   юго-западный административный округ
# 1          южный административный округ
# 2          южный административный округ
# 3          южный административный округ
# 4          южный административный округ
# 5          южный административный округ
# 6          южный административный округ
# 7          южный административный округ
# 8          южный административный округ
# 9       западный административный округ
# 12      северный административный округ
# 13      северный административный округ
# 10      северный административный округ
# 11      северный административный округ
# 14  юго-западный административный округ
# 15  юго-западный административный округ
# 16         южный административный округ
# 17      западный административный округ
# 18  юго-западный административный округ
# 20   центральный административный округ
# 26      западный административный округ
# 21      западный административный округ
# 27  юго-западный административный округ
# 22   центральный административный округ
# 23  юго-западный административный округ
# 24  юго-западный административный округ
# 25  юго-западный административный округ

# %% [markdown]
# Построим график 'Топ-10 улиц г.Москва по количеству общественного питания':

# %%
# Построим sns.barplot() из библиотеки seaborn:
plt.figure(figsize = (15,10))
sns.barplot(y = 'street', x = 'object_name', data = street_table_result)
plt.title('Топ-10 улиц г.Москва по количеству общественного питания', pad = 20)
plt.ylabel('Название улицы')

plt.legend((['пр. Мира: Мещанский (ЦАО)', 'Профсоюзная: Коньково, Тёплый Стан, Ясенево (ЮЗАО)',\
            'пр.Ленинградский: Аэропорт, Xорошёвский, Беговой (САО)','Пресненская набережная: Пресненский (ЦАО)',\
            'Варшавское шоссе: Юж. и Сев.Бутово (ЮЗАО)',\
            'пр.Ленинский: Проспект Вернадского , Тёплый Стан, Тропарёво-Никулино, Ломоносовский, \
            Обручевский, Гагаринский, Донской (ЮЗАО, ЗАО, ЮАО)',\
            'пр.Вернадского: Раменки, Проспект Вернадского, Гагаринский, Ломоносовский (ЗАО, ЮЗАО)', \
            'пр.Кутузовский: Дорогомилово (ЗАО)',\
            'Каширское шоссе: Mоскворечье-Cабурово, Нагатино-Садовники, Нагорный, Юж. и Сев. Орехово-Борисово(ЮАО)',\
           'Кировградская: Юж. Сев. и Центр. Чертаново (ЮАО)']),
     title = 'Районы и округа г.Москва для топ-10 улиц',
          bbox_to_anchor = (0.8, -0.1))
plt.xlabel('Количество')
plt.xticks(rotation='90')
plt.show()

# %% [markdown]
# ### *Вывод:*
#
# *Перед нами список районов, в которых расположены топ-10 улиц г.Москва по количеству общественного питания.*
#
# *Улицы имеют большую протяженность и охватывают несколько районов.*
#
# *Данные улицы расположены в округах: центральный, западный, юго-западный, южный, северный.*
#
# *Больше всех заведений общественного питания расположено на пр.Мира в Центральном административном округе: ~200.*

# %% [markdown]
# 6.	Найдем число улиц с одним объектом общественного питания. Воспользуемся внешней информацией и ответим на вопрос — в каких районах Москвы находятся эти улицы?

# %% [markdown]
# Выведем на экран датафрейм df:

# %%
df.head(5)
# Out:
#        id             object_name chain object_type  \
# 0  151635                 сметана   нет        кафе
# 1   77874                  родник   нет        кафе
# 2   24309         кафе «академия»   нет        кафе
# 3   21894              пиццетория    да        кафе
# 4  119365  кафе «вишневая метель»   нет        кафе
#
#                                              address  number  object_name_new  \
# 0         город Москва, улица Егора Абакумова, дом 9      48          сметана
# 1  город Москва, улица Талалихина, дом 2/1, корпус 1      35           родник
# 2          город Москва, Абельмановская улица, дом 6      95         академия
# 3            город Москва, Абрамцевская улица, дом 1      40       пиццетория
# 4  город Москва, Абрамцевская улица, дом 9, корпус 1      50  вишневая метель
#
#                   street
# 0  улица Егора Абакумова
# 1       улица Талалихина
# 2   Абельмановская улица
# 3     Абрамцевская улица
# 4     Абрамцевская улица

# %% [markdown]
# Итак, чтобы найти число улиц с одним объектом общественного питания, сгруппируем данные по улице, найдем количество на каждой. И выведем на экран нужные улицы = 1. Найдем количество:

# %%
street_one = df[df['street'] != ''].groupby('street').agg({'object_name': 'count'}).reset_index()
street_one = street_one[street_one['object_name'] == 1]
street_one['street'].count()
# Out:
# 628

# %% [markdown]
# *В итоге получили:  на 628 улицах г.Москвы расположено одно заведение общественного питания.*
#
# Сейчас выведем на экран районы. Поступим также как и в предыдущем случае. Обратимся к данным сайта OpenStreetMap и воспользуемся уже созданной функцией, которая будет отправлять запрос на указанный выше сайт и сохранять в словарь название района:

# %%
# Добавим к названию улицы название города Москва, это нужно для формирования нужного запроса на OpenStreetMap
street_one['street'] = "Москва, " + street_one['street']
street_one.head()
# Out:
#                               street  object_name
# 2    Москва, 1-й Балтийский переулок            1
# 3     Москва, 1-й Басманный переулок            1
# 4    Москва, 1-й Ботанический проезд            1
# 7    Москва, 1-й Вешняковский проезд            1
# 9  Москва, 1-й Голутвинский переулок            1

# %% [markdown]
# Формируем запрос:

# %%
content = [] # создаем пустой список
query = street_one['street'] # передаем query столбец
    # создаем цикл: перебираем нужные нам адреса:
for i in query:
        # сохраняем get запрос в переменную response; адрес i будем передавать в query={}.format(i)
        response = requests.get('https://www.openstreetmap.org/geocoder/search_osm_nominatim?query={}'.format(i))
        # к тексту ответа запроса применим парсер 'lxml', создав дерево сайта с помощью BeautifulSoup:
        soup = BeautifulSoup(response.text, 'lxml')
        # находим нужную нам информацию
        table = soup.find_all('a', attrs = {'class': 'set_position'})
        # сохраняем текст в список:
        for y in soup.find_all('a', attrs = {'class': 'set_position'}):
            content.append(y.text)

# %%
# Сохраняем данные из полученного списка в датафрейм:
new_one = pd.DataFrame()
new_one['content'] = content
new_one['content'].values

# %% [markdown]
# Добавляем к датафрейму new_one столбец area - название района, поселения, городского округа:

# %%
pattern = ',\ ([\w\-\w]+ (район|городской округ|городок|поселение|посёлок|городок|поле)|\
         (район|городской округ|поселение|посёлок) [\w\-\w\s\w]*)\,'
new_one['area'] = new_one['content'].str.findall(pat = pattern)
new_one['area'] = new_one['content'].str.extract(pat = pattern)
new_one.sample(20)

# %% [markdown]
# Заменим пропуски на пустое значение:

# %%
new_one['area'] = new_one['area'].fillna('')

# %% [markdown]
# Добавим столбец с названием округа: с помощью регулярного выражения найдем в столбце content название округа и сохраним его в новый столбец okrug:

# %%
pattern = ',\ ([\w+\-\w+]* административный округ|Московская область)\,'
new_one['okrug'] = new_one['content'].str.findall(pat = pattern)
new_one['okrug'] = new_one['content'].str.extract(pat = pattern)
new_one.sample(5)

# %% [markdown]
# Проверим, если ли в столбце okrug пропущенные значения:

# %%
new_one.info()

# %% [markdown]
# В трех ячейках имеются пропущенные значения. По отношению к общему числу строк в датафрейме процент очень не велик. Оставляем строки.
#
# Преобразуем данные в таблице следующим образом: в столбце content оставляем только название улицы, во всей таблице данные приводим к нижнему регистру, удалим дубликаты:

# %%
# Оставляем название улицы в первом столбце:
new_one['content'] = new_one['content'].str.split('\,').str[0]
# Приводим к нижнему регистру данные в столбцах area и okrug:
new_one['okrug'] = new_one['okrug'].str.lower()
new_one['area'] = new_one['area'].str.lower()
# Удаляем дубликаты и меняем индексы в таблице, чтобы счет был последовательный:
new_one = new_one.drop_duplicates().reset_index(drop = True)
new_one.sample(10)

# %% [markdown]
# Сейчас сгруппируем данные таблицы new_one по округу и найдем количество улиц в каждом:

# %%
okrug_one = new_one.groupby('okrug').agg({'content': 'count'}).reset_index()
# Переименуем столбец:
okrug_one = okrug_one.rename(columns = {'content': 'street_count'})
okrug_one.sort_values(by = 'street_count', ascending = False)

# %%
plt.figure(figsize = (15,10))
sns.barplot(y = 'okrug', x = 'street_count', data = okrug_one)
plt.title('Количество улиц с одним объектом общественного питания по округам Москвы', pad = 20)
plt.ylabel('Название')
plt.xlabel('Количество')
plt.show()

# %% [markdown]
# ### *Вывод:*
#
# *Больше всего улиц с одним объектом общественного питания находится в центральном административном округе: ~200 и в Московской области.*

# %% [markdown]
# 7.	Посмотрим на распределение количества посадочных мест для улиц с большим количеством объектов общественного питания. Ответим на вопрос: какие закономерности можно выявить?

# %% [markdown]
# Выведем на экран таблицу "Топ-10 улиц г.Москва по количеству посадочных мест":

# %%
street_table_result

# %% [markdown]
# Сейчас отфильтруем указанные улицы в таблице df. Для этого создадим список содержащий название улиц и применим метод query() к столбцу street:

# %%
# Создаем список:
list_ = ['проспект Мира', 'Профсоюзная улица', 'Ленинградский проспект', 'Пресненская набережная',\
        'Варшавское шоссе', 'Ленинский проспект', 'проспект Вернадского', 'Кутузовский проспект', \
         'Каширское шоссе', 'Кировоградская улица']

# %%
street_top = df.query('street in @list_')
street_top.sample(5)

# %% [markdown]
# Построим распределение данных:

# %%
plt.figure(figsize = (15,10))
sns.distplot(street_top['number'], bins = 50)
plt.title('Распределение посадочных мест в заведениях топ-10 улиц г.Москва')
plt.xlabel('Количество')
plt.show()

# %% [markdown]
# *Распределение имеет положительную ассиметрию: наблюдается перекос вправо и очень длинный хвост высоких значений.*
#
# *На графике видно, что в некоторых заведениях количество посадочных мест больше 1500. Возможно это выбросы.*
#
# *Основная масса заведений имеет от 0 до ~150 посадочных мест.*

# %% [markdown]
# Вычислим 90, 95 и 99 перцентили для распределения данных:

# %%
np.percentile(street_top['number'], [90,95,99])

# %% [markdown]
# Сейчас сгруппируем данные number - число посадочных мест по улицам найдем медиану для каждой группы:

# %%
street_top.groupby('street').agg({'number': 'median'}).T

# %% [markdown]
# Нарисуем график:

# %%
plt.figure(figsize = (20,15))
sns.violinplot(x = 'street', y = 'number', data = street_top, split=True)
plt.title('Количество посадочных мест для заведений топ-10 улиц города Москвы')
plt.xlabel('Название улицы')
plt.ylabel('Количество посадочных мест')
plt.show()

# %% [markdown]
# ### *Вывод:*
#
# *В 50% заведений на всех топ-10 улицах количество посадочных мест не больше ~ 40-50.*
#
# *Не более чем в 10% заведений количество  посадочных мест больше 140.*
#
# *Не более чем в 5% заведений количество посадочных мест больше 200.*
#
# *И не более чем в 1% заведений превышает 300.*

# %% [markdown]
# # Вывод:
#
# В ходе исследования были получены следующие результаты:
#
# 1.

# %%
# Построим sns.countplot() из библиотеки seaborn:
plt.figure(figsize = (15,10))
sns.countplot(x = 'object_type', data = df, order = type_count['index'])
plt.title('Соотношение видов общественного питания по количеству в г.Москва', pad = 20)
plt.xlabel('Вид общественного питания')
plt.ylabel('Количество')
plt.xticks(rotation='90')
plt.show()

# %% [markdown]
# В г.Москва больше всех заведений общественного питания с типом 'Кафе': ~6000.
#
# С типом: 'Столовая': ~2500, 'Ресторан': ~2200, 'Предприятие быстрого обслуживания': ~1900.
#
# С типом: 'Бар': ~850, 'Буфет': ~600, 'Кафетерий' и 'Закусочная': ~400
#
# Меньше всех заведений общественного питания с типом 'Отдел кулинарии'(в магазинах): ~300.

# %% [markdown]
# 2. В г.Москва, в основном, заведения общественного питания не являются сетевыми: ~ 80,7%. И только ~ 19,3% - являются сетевыми.

# %% [markdown]
# 3. Сетевое распространение характерно для всех типов заведений общественного питания. Но, в основном, для заведений типа: кафе, предприятие быстрого обслуживания, ресторан.

# %% [markdown]
# 4. Для сетевых заведений характерно: много заведений с относительно небольшим числом посадочных мест в каждом.

# %%
# Построим "ящик с усами"
plt.figure(figsize = (15,10))
sns.boxplot(x = 'chain', data = col)
plt.xlim(-2, 20)
plt.title("Распределение количества заведений в сетях")
plt.xlabel('Количество заведений')
plt.show()

# %% [markdown]
# Для сетей общественного питания характерно наличие нескольких заведений в конкретном городе, стране, мире. Например, "Бургер Кинг", "Макдоналдс", "KFC" - крупные сети. Их бренд знают во всем мире.
#
# Разделим сети Москвы на две группы:
#
# •	крупные с раскрученным брендом;
#
# •	мелкие, развивающиеся сети.
#
# Количество заведений в мелких развивающихся сетях в Москве: от 2 до 13.
# Количество заведений в крупных сетях с раскрученным брендом составляет от 13 и выше.

# %% [markdown]
# 5. Количество посадочных мест в сетевых заведениях:

# %%
# Построим "ящик с усами"
plt.figure(figsize = (15,10))
sns.boxplot(x = 'number', data = df_chain_yes, color = 'darkorange')
plt.xlim(-20, 300)
plt.title("Распределение посадочных мест в сетевых заведениях")
plt.xlabel('Количество посадочных мест')
plt.show()

# %% [markdown]
# Медианное количество посадочных мест в сетевых заведениях: ~40. То есть:
#
# В 50% всех заведений количество посадочных мест лежит в диапазоне от 0 до 40.
#
# В остальных 50% заведениях: количество посадочных мест составляет: 40 - 300.

# %% [markdown]
# 6. Результаты исследования посадочных мест по типу заведения следующие:
#
# *КАФЕ: среднее количество посадочных мест ~30. Для 95% заведений число не превышает 100. И лишь для 1% число мест превышает 190.*
#
# *СТОЛОВАЯ: среднее количество посадочных мест ~103. Для 95% заведений число не превышает 300. И лишь для 1% число мест превышает 330.*
#
# *ЗАКУСОЧНАЯ: 50% заведений не имеют посадочных мест. Остальные 50% имеют  небольшое количество. Не более в 10% число мест превышает 22. Не более в 5% - превышает 35.И лишь для 1% число мест превышает 60.*
#
# *ПРЕДПРИЯТИЕ БЫСТРОГО ОБСЛУЖИВАНИЯ: среднее количество посадочных мест ~5.  Не более в 10% число мест превышает 60. Не более в 5% - превышает 92.И лишь для 1% число мест превышает 170.*
#
# *РЕСТОРАН: среднее количество посадочных мест ~80.  Не более в 10% число мест превышает 180. Не более в 5% - превышает 250.И лишь для 1% число мест превышает 500.*
#
# *КАФЕТЕРИЙ: среднее количество посадочных мест ~6.  Не более в 10% число мест превышает 21. Не более в 5% - превышает 30.И лишь для 1% число мест превышает 50.*
#
# *БУФЕТ: среднее количество посадочных мест ~32.  Не более в 10% число мест превышает 120. Не более в 5% - превышает 170. И лишь для 1% число мест превышает 250.*
#
# *БАР: среднее количество посадочных мест ~35.  Не более в 10% число мест превышает 85. Не более в 5% - превышает 100. И лишь для 1% число мест превышает 180.*
#
# *МАГАЗИН(ОТДЕЛ КУЛИНАРИИ): 50% заведений не имеют посадочных мест. Остальные 50% имеют  небольшое количество.  Не более в 10% число мест превышает 15. Не более в 5% - превышает 30. И лишь для 1% число мест превышает 40.*
#
# *Итак, самое большое число посадочных мест предоставляет заведение общественного питания с типом: столовая.*

# %% [markdown]
# 7. Топ-10 улиц г. Москва где сосредоточено больше всех заведений:

# %%
# Построим sns.barplot() из библиотеки seaborn:
plt.figure(figsize = (15,10))
sns.barplot(y = 'street', x = 'object_name', data = street_table_result)
plt.title('Топ-10 улиц г.Москва по количеству общественного питания', pad = 20)
plt.ylabel('Название улицы')

plt.legend((['пр. Мира: Мещанский (ЦАО)', 'Профсоюзная: Коньково, Тёплый Стан, Ясенево (ЮЗАО)',\
            'пр.Ленинградский: Аэропорт, Xорошёвский, Беговой (САО)','Пресненская набережная: Пресненский (ЦАО)',\
            'Варшавское шоссе: Юж. и Сев.Бутово (ЮЗАО)',\
            'пр.Ленинский: Проспект Вернадского , Тёплый Стан, Тропарёво-Никулино, Ломоносовский, \
            Обручевский, Гагаринский, Донской (ЮЗАО, ЗАО, ЮАО)',\
            'пр.Вернадского: Раменки, Проспект Вернадского, Гагаринский, Ломоносовский (ЗАО, ЮЗАО)', \
            'пр.Кутузовский: Дорогомилово (ЗАО)',\
            'Каширское шоссе: Mоскворечье-Cабурово, Нагатино-Садовники, Нагорный, Юж. и Сев. Орехово-Борисово(ЮАО)',\
           'Кировградская: Юж. Сев. и Центр. Чертаново (ЮАО)']),
     title = 'Районы и округа г.Москва для топ-10 улиц',
          bbox_to_anchor = (0.8, -0.1))
plt.xlabel('Количество')
plt.xticks(rotation='90')
plt.show()

# %% [markdown]
# Улицы имеют большую протяженность и охватывают несколько районов.
#
# Данные улицы расположены в округах: центральный, западный, юго-западный, южный, северный.
#
# Больше всех заведений общественного питания расположено на пр.Мира в Центральном административном округе: ~200.

# %% [markdown]
# 8.

# %%
plt.figure(figsize = (20,15))
sns.violinplot(x = 'street', y = 'number', data = street_top, split=True)
plt.title('Количество посадочных мест для заведений топ-10 улиц города Москвы')
plt.xlabel('Название улицы')
plt.ylabel('Количество посадочных мест')
plt.show()

# %% [markdown]
# В 50% заведений на всех топ-10 улицах количество посадочных мест не больше ~ 40-50.
#
# Не более чем в 10% заведений количество посадочных мест больше 140.
#
# Не более чем в 5% заведений количество посадочных мест больше 200.
#
# И не более чем в 1% заведений превышает 300.

# %% [markdown]
# 9. Были выявлены улицы, на которых расположен один объект общественного питания:

# %%
plt.figure(figsize = (15,10))
sns.barplot(y = 'okrug', x = 'street_count', data = okrug_one)
plt.title('Количество улиц с одним объектом общественного питания по округам Москвы', pad = 20)
plt.ylabel('Название')
plt.xlabel('Количество')
plt.show()

# %% [markdown]
# На 628 улицах г.Москвы расположено одно заведение общественного питания.
#
# Больше всего улиц с одним объектом общественного питания находится  в центральном административном округе: ~200 и Московской области: ~250.

# %% [markdown]
# # Рекомендации:

# %% [markdown]
# 1. Тип открывающегося объекта общественного питания: "кафе";
#
# 2. Число посадочных мест: ~ от 50 до 100;
#
# 3. Место расположения: Центральный административный округ г.Москвы.

# %% [markdown]
# # Приложения:

# %% [markdown]
# [Презентация](https://yadi.sk/i/y-2mJrN9MFGULQ)

# %% [markdown]
# Таблица, содержащая улицы с одним объектом общественного питания в ЦАО Москвы:

# %%
result_total = new_one[new_one['okrug'] == 'центральный административный округ']
